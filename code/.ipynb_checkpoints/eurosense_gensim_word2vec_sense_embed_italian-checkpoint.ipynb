# %% [markdown]
# ## Imports, as always!

# %%
import logging
from gensim.models import Word2Vec
import numpy as np
import matplotlib.pyplot as plt

from corpora_it import *
from my_utils import *
import score_it

# %% [markdown]
# ## Parsing Corpora

# %%
corpora_path = '../EuroSense/eurosense.v1.0.high-precision.xml'
bn2wn_mapping_path = '../resources/bn2wn_mapping.txt'
outfile_path = './EuroSense/parsed_ita_stp/sentences_precision.txt'

parse(corpora_path, bn2wn_mapping_path, outfile_path, "precision")
#1,560,539 sentences

# %%
corpora_path = '../EuroSense/EuroSense/eurosense.v1.0.high-coverage.xml'
bn2wn_mapping_path = '../resources/bn2wn_mapping.txt'
outfile_path = '../EuroSense/parsed_ita_stp/sentenses_coverage.txt'

parse(corpora_path, bn2wn_mapping_path, outfile_path, "coverage")
#1,560,557 sentences

# %%
bn2wn_mapping_path = '../resources/bn2wn_mapping.txt'
sentences_p = InputSentences('../EuroSense/parsed_ita_stp/sentences_precision.txt')
sentences_c = InputSentences('../EuroSense/parsed_ita_stp/sentences_coverage.txt')
sentences_folder = InputSentences('../EuroSense/parsed_ita_stp/')
test_data_path = "../wordsim353/combined.tab"

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# ## Training the Model

# %% [markdown]
# ### Merged Data

# %%
embeddings_path = "../resources/ita_embeddings_size{}_win{}_neg{}_lr{}_epo{}.vec".format(100, 6, 20, 0.09, 10)

model = Word2Vec(sentences_folder, workers=5, size=100, window=6, alpha=0.09, negative=20, iter=10)

# %%
save_embeddings(embeddings_path, model.wv)
corr, p, data = score_it.spearman(test_data_path, embeddings_path, bn2wn_mapping_path)
# Out:
# 2019-06-06 07:24:29,134 : INFO : loading projection weights from ../resources/ita_embeddings_size100_win6_neg20_lr0.09_epo10.vec
# 2019-06-06 07:24:29,137 : WARNING : this function is deprecated, use smart_open.open instead
# 2019-06-06 07:24:38,292 : INFO : loaded (34967, 100) matrix from ../resources/ita_embeddings_size100_win6_neg20_lr0.09_epo10.vec
# C:\Anaconda3\lib\site-packages\scipy\stats\stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)

# %%
print(corr)
print(len(model.wv.vocab))
# Out:
# 0.17436966517177743
# 98255

# %%
data
# Out:
# [['love', 'sex', '6.77', 0.31707254],
#  ['tiger', 'cat', '7.35', 0.42046824],
#  ['tiger', 'tiger', '10.00', 0.9999999],
#  ['book', 'paper', '7.46', 0.3532274],
#  ['computer', 'keyboard', '7.62', 0.0],
#  ['computer', 'internet', '7.58', 0.547773],
#  ['plane', 'car', '5.77', 0.62867016],
#  ['train', 'car', '6.31', 0.73887116],
#  ['telephone', 'communication', '7.50', 0.18552814],
#  ['television', 'radio', '6.77', 0.67359895],
#  ['media', 'radio', '7.42', 0.0],
#  ['drug', 'abuse', '6.85', 0.37476996],
#  ['bread', 'butter', '6.19', 0.49977204],
#  ['cucumber', 'potato', '5.92', 0.5149471],
#  ['doctor', 'nurse', '7.00', 0.7737671],
#  ['professor', 'doctor', '6.62', 0.6317605],
#  ['student', 'professor', '6.81', 0.690903],
#  ['smart', 'student', '4.62', 0.20862731],
#  ['smart', 'stupid', '5.81', 0.4425469],
#  ['company', 'stock', '7.08', 0.32091326],
#  ['stock', 'market', '8.08', 0.39064485],
#  ['stock', 'phone', '1.62', 0.36292696],
#  ['stock', 'CD', '1.31', 0.23048355],
#  ['stock', 'jaguar', '0.92', 0.0],
#  ['stock', 'egg', '1.81', 0.48943385],
#  ['fertility', 'egg', '6.69', 0.45965132],
#  ['stock', 'live', '3.73', 0.46026018],
#  ['stock', 'life', '0.92', 0.36073792],
#  ['book', 'library', '7.46', 0.30156836],
#  ['bank', 'money', '8.12', 0.6382686],
#  ['wood', 'forest', '7.73', 1.0000001],
#  ['money', 'cash', '9.15', 0.46903086],
#  ['professor', 'cucumber', '0.31', 0.0],
#  ['king', 'cabbage', '0.23', 0.33409604],
#  ['king', 'queen', '8.58', 0.19404438],
#  ['king', 'rook', '5.92', 0.39524084],
#  ['bishop', 'rabbi', '6.69', 0.13151392],
#  ['Jerusalem', 'Israel', '8.46', 0.0],
#  ['Jerusalem', 'Palestinian', '7.65', 0.0],
#  ['holy', 'sex', '1.62', 0.3810468],
#  ['fuck', 'sex', '9.44', 0.22590882],
#  ['Maradona', 'football', '8.62', 0.0],
#  ['football', 'soccer', '9.03', 0.21053918],
#  ['football', 'basketball', '6.81', 0.11753083],
#  ['football', 'tennis', '6.63', 0.14742003],
#  ['tennis', 'racket', '7.56', 0.12756567],
#  ['Arafat', 'peace', '6.73', 0.0],
#  ['Arafat', 'terror', '7.65', 0.0],
#  ['Arafat', 'Jackson', '2.50', 0.0],
#  ['law', 'lawyer', '8.38', 0.48295045],
#  ['movie', 'star', '7.38', 0.6852746],
#  ['movie', 'popcorn', '6.19', 0.0],
#  ['movie', 'critic', '6.73', 0.22226064],
#  ['movie', 'theater', '7.92', 0.39607635],
#  ['physics', 'proton', '8.12', 0.0],
#  ['physics', 'chemistry', '7.35', 0.5070264],
#  ['space', 'chemistry', '4.88', 0.17238493],
#  ['alcohol', 'chemistry', '5.54', 0.27083772],
#  ['vodka', 'gin', '8.46', 0.6264048],
#  ['vodka', 'brandy', '8.13', 0.6689348],
#  ['drink', 'car', '3.04', 0.39408553],
#  ['drink', 'ear', '1.31', 0.33971056],
#  ['drink', 'mouth', '5.96', 0.5023053],
#  ['drink', 'eat', '6.87', 0.7649271],
#  ['baby', 'mother', '7.85', 0.61833227],
#  ['drink', 'mother', '2.65', 0.3441354],
#  ['car', 'automobile', '8.94', 1.0],
#  ['gem', 'jewel', '8.96', 1.0000001],
#  ['journey', 'voyage', '9.29', 0.5097884],
#  ['boy', 'lad', '8.83', 0.36224312],
#  ['coast', 'shore', '9.10', 0.8484912],
#  ['asylum', 'madhouse', '8.87', 0.0],
#  ['magician', 'wizard', '9.02', 1.0000001],
#  ['midday', 'noon', '9.29', 0.99999994],
#  ['furnace', 'stove', '8.79', 0.32763594],
#  ['food', 'fruit', '7.52', 0.5131392],
#  ['bird', 'cock', '7.10', 0.0],
#  ['bird', 'crane', '7.38', 0.228151],
#  ['tool', 'implement', '6.46', 0.75204927],
#  ['brother', 'monk', '6.27', 0.39357728],
#  ['crane', 'implement', '2.69', 0.26650527],
#  ['lad', 'brother', '4.46', 0.1665419],
#  ['journey', 'car', '5.85', 0.49117678],
#  ['monk', 'oracle', '5.00', 0.0],
#  ['cemetery', 'woodland', '2.08', 0.0],
#  ['food', 'rooster', '4.42', 0.0],
#  ['coast', 'hill', '4.38', 0.5477474],
#  ['forest', 'graveyard', '1.85', 0.25851434],
#  ['shore', 'woodland', '3.08', 0.0],
#  ['monk', 'slave', '0.92', 0.34940562],
#  ['coast', 'forest', '3.15', 0.4848103],
#  ['lad', 'wizard', '0.92', 0.250309],
#  ['chord', 'smile', '0.54', 0.06675787],
#  ['glass', 'magician', '2.08', 0.3112669],
#  ['noon', 'string', '0.54', 0.20248713],
#  ['rooster', 'voyage', '0.62', 0.0],
#  ['money', 'dollar', '8.42', 0.32230043],
#  ['money', 'cash', '9.08', 0.46903086],
#  ['money', 'currency', '9.04', 0.7625019],
#  ['money', 'wealth', '8.27', 0.386761],
#  ['money', 'property', '7.57', 0.3200472],
#  ['money', 'possession', '7.29', 0.3852032],
#  ['money', 'bank', '8.50', 0.6382686],
#  ['money', 'deposit', '7.73', 0.36931983],
#  ['money', 'withdrawal', '6.88', 0.33800998],
#  ['money', 'laundering', '5.65', 0.404497],
#  ['money', 'operation', '3.31', 0.20850772],
#  ['tiger', 'jaguar', '8.00', 0.0],
#  ['tiger', 'feline', '8.00', 0.0],
#  ['tiger', 'carnivore', '7.08', 0.0],
#  ['tiger', 'mammal', '6.85', 0.3567084],
#  ['tiger', 'animal', '7.00', 0.42041266],
#  ['tiger', 'organism', '4.77', 0.2078918],
#  ['tiger', 'fauna', '5.62', 0.42041266],
#  ['tiger', 'zoo', '5.87', 0.1124742],
#  ['psychology', 'psychiatry', '8.08', 0.41436088],
#  ['psychology', 'anxiety', '7.00', 0.3386672],
#  ['psychology', 'fear', '6.85', 0.37710536],
#  ['psychology', 'depression', '7.42', 0.25695676],
#  ['psychology', 'clinic', '6.58', 0.32841447],
#  ['psychology', 'doctor', '6.42', 0.66826004],
#  ['psychology', 'Freud', '8.21', 0.0],
#  ['psychology', 'mind', '7.69', 0.4729339],
#  ['psychology', 'health', '7.23', 0.13834664],
#  ['psychology', 'science', '6.71', 0.3821358],
#  ['psychology', 'discipline', '5.58', 0.27135336],
#  ['psychology', 'cognition', '7.48', 0.41364303],
#  ['planet', 'star', '8.45', 0.29482388],
#  ['planet', 'constellation', '8.06', 0.103079006],
#  ['planet', 'moon', '8.08', 0.27694035],
#  ['planet', 'sun', '8.02', 0.44569436],
#  ['planet', 'galaxy', '8.11', 0.48639783],
#  ['planet', 'space', '7.92', 0.20487322],
#  ['planet', 'astronomer', '7.94', 0.1987428],
#  ['precedent', 'example', '5.85', 0.39547944],
#  ['precedent', 'information', '3.85', 0.13744287],
#  ['precedent', 'cognition', '2.81', 0.16183366],
#  ['precedent', 'law', '6.65', 0.14285848],
#  ['precedent', 'collection', '2.50', 0.17865805],
#  ['precedent', 'group', '1.77', 0.23148471],
#  ['precedent', 'antecedent', '6.04', 0.21952935],
#  ['cup', 'coffee', '6.58', 0.453374],
#  ['cup', 'tableware', '6.85', 0.12368195],
#  ['cup', 'article', '2.40', 0.20067339],
#  ['cup', 'artifact', '2.92', 0.0],
#  ['cup', 'object', '3.69', 0.23242436],
#  ['cup', 'entity', '2.15', 0.23748632],
#  ['cup', 'drink', '7.25', 0.30224195],
#  ['cup', 'food', '5.00', 0.21791308],
#  ['cup', 'substance', '1.92', 0.12853841],
#  ['cup', 'liquid', '5.90', 0.110057965],
#  ['jaguar', 'cat', '7.42', 0.0],
#  ['jaguar', 'car', '7.27', 0.0],
#  ['energy', 'secretary', '1.81', 0.19114868],
#  ['secretary', 'senate', '5.06', 0.274017],
#  ['energy', 'laboratory', '5.09', 0.13968375],
#  ['computer', 'laboratory', '6.78', 0.38262576],
#  ['weapon', 'secret', '6.06', 0.14736892],
#  ['FBI', 'fingerprint', '6.94', 0.0],
#  ['FBI', 'investigation', '8.31', 0.0],
#  ['investigation', 'effort', '4.59', 0.451451],
#  ['Mars', 'water', '2.94', 0.0],
#  ['Mars', 'scientist', '5.63', 0.0],
#  ['news', 'report', '8.16', 0.3965699],
#  ['canyon', 'landscape', '7.53', 0.0],
#  ['image', 'surface', '4.56', 0.3895698],
#  ['discovery', 'space', '6.34', 0.25083134],
#  ['water', 'seepage', '6.56', 0.0],
#  ['sign', 'recess', '2.38', 0.28572217],
#  ['Wednesday', 'news', '2.22', 0.0],
#  ['mile', 'kilometer', '8.66', 0.73166686],
#  ['computer', 'news', '4.47', 0.43728498],
#  ['territory', 'surface', '5.34', 0.25525546],
#  ['atmosphere', 'landscape', '3.69', 0.0],
#  ['president', 'medal', '3.00', 0.24044152],
#  ['war', 'troops', '8.13', 0.33924454],
#  ['record', 'number', '6.31', 0.50402135],
#  ['skin', 'eye', '6.22', 0.22392492],
#  ['Japanese', 'American', '6.50', 0.0],
#  ['theater', 'history', '3.91', 0.48121974],
#  ['volunteer', 'motto', '2.56', 0.22731955],
#  ['prejudice', 'recognition', '3.00', 0.16611981],
#  ['decoration', 'valor', '5.63', 0.2626509],
#  ['century', 'year', '7.59', 0.54957044],
#  ['century', 'nation', '3.16', 0.2585548],
#  ['delay', 'racism', '1.19', 0.18112892],
#  ['delay', 'news', '3.31', 0.2132979],
#  ['minister', 'party', '6.63', 0.32896948],
#  ['peace', 'plan', '4.75', 0.27275482],
#  ['minority', 'peace', '3.69', 0.18480814],
#  ['attempt', 'peace', '4.25', 0.42606303],
#  ['government', 'crisis', '6.56', 0.2749982],
#  ['deployment', 'departure', '4.25', 0.17299818],
#  ['deployment', 'withdrawal', '5.88', 0.60090333],
#  ['energy', 'crisis', '5.94', 0.21809864],
#  ['announcement', 'news', '7.56', 0.41960627],
#  ['announcement', 'effort', '2.75', 0.37312007],
#  ['stroke', 'hospital', '7.03', 0.2810248],
#  ['disability', 'death', '5.47', 0.59618384],
#  ['victim', 'emergency', '6.47', 0.3232407],
#  ['treatment', 'recovery', '7.91', 0.5666956],
#  ['journal', 'association', '4.97', 0.3016235],
#  ['doctor', 'personnel', '5.00', 0.30103236],
#  ['doctor', 'liability', '5.19', 0.1904593],
#  ['liability', 'insurance', '7.03', 0.31757963],
#  ['school', 'center', '3.44', 0.53921646],
#  ['reason', 'hypertension', '2.31', 0.27809826],
#  ['reason', 'criterion', '5.91', 0.40084264],
#  ['hundred', 'percent', '7.38', 0.9597825],
#  ['Harvard', 'Yale', '8.13', 0.0],
#  ['hospital', 'infrastructure', '4.63', 0.37786546],
#  ['death', 'row', '5.25', 0.33902478],
#  ['death', 'inmate', '5.03', 0.46683753],
#  ['lawyer', 'evidence', '6.69', 0.32817703],
#  ['life', 'death', '7.88', 0.3647508],
#  ['life', 'term', '4.50', 0.29256225],
#  ['word', 'similarity', '4.75', 0.32133228],
#  ['board', 'recommendation', '4.47', 0.33723745],
#  ['governor', 'interview', '3.25', 0.35362095],
#  ['OPEC', 'country', '5.63', 0.0],
#  ['peace', 'atmosphere', '3.69', 0.20172264],
#  ['peace', 'insurance', '2.94', 0.008171414],
#  ['territory', 'kilometer', '5.28', 0.3405868],
#  ['travel', 'activity', '5.00', 0.21079735],
#  ['competition', 'price', '6.44', 0.45231265],
#  ['consumer', 'confidence', '4.13', 0.37344483],
#  ['consumer', 'energy', '4.75', 0.2589151],
#  ['problem', 'airport', '2.38', 0.18652214],
#  ['car', 'flight', '4.94', 0.5297019],
#  ['credit', 'card', '8.06', 0.31262037],
#  ['credit', 'information', '5.31', 0.30759916],
#  ['hotel', 'reservation', '8.03', 0.42242983],
#  ['grocery', 'money', '5.94', 0.27628776],
#  ['registration', 'arrangement', '6.00', 0.20860058],
#  ['arrangement', 'accommodation', '5.41', 0.4990161],
#  ['month', 'hotel', '1.81', 0.29815927],
#  ['type', 'kind', '8.97', 0.81866145],
#  ['arrival', 'hotel', '6.00', 0.39077455],
#  ['bed', 'closet', '6.72', 0.37020418],
#  ['closet', 'clothes', '8.00', 0.0],
#  ['situation', 'conclusion', '4.81', 0.5943885],
#  ['situation', 'isolation', '3.88', 0.30633065],
#  ['impartiality', 'interest', '5.16', 0.32873374],
#  ['direction', 'combination', '2.25', 0.3494603],
#  ['street', 'place', '6.44', 0.40923032],
#  ['street', 'avenue', '8.88', 0.21159084],
#  ['street', 'block', '6.88', 0.19742997],
#  ['street', 'children', '4.94', 0.0],
#  ['listing', 'proximity', '2.56', 0.03601261],
#  ['listing', 'category', '6.38', 0.42390183],
#  ['cell', 'phone', '7.81', 0.70932245],
#  ['production', 'hike', '1.75', 0.39644757],
#  ['benchmark', 'index', '4.25', 0.20304853],
#  ['media', 'trading', '3.88', 0.0],
#  ['media', 'gain', '2.88', 0.0],
#  ['dividend', 'payment', '7.63', 0.36255416],
#  ['dividend', 'calculation', '6.48', 0.16269526],
#  ['calculation', 'computation', '8.44', 1.0000001],
#  ['currency', 'market', '7.50', 0.33636808],
#  ['OPEC', 'oil', '8.59', 0.0],
#  ['oil', 'stock', '6.34', 0.42791918],
#  ['announcement', 'production', '3.38', 0.3166891],
#  ['announcement', 'warning', '6.00', 0.3345712],
#  ['profit', 'warning', '3.88', 0.2937675],
#  ['profit', 'loss', '7.63', 0.43022496],
#  ['dollar', 'yen', '7.78', 0.5584906],
#  ['dollar', 'buck', '9.22', 0.0],
#  ['dollar', 'profit', '7.38', 0.27844563],
#  ['dollar', 'loss', '6.09', 0.16225679],
#  ['computer', 'software', '8.50', 0.6030259],
#  ['network', 'hardware', '8.31', 0.24275053],
#  ['phone', 'equipment', '7.13', 0.5512705],
#  ['equipment', 'maker', '5.91', 0.44513634],
#  ['luxury', 'car', '6.47', 0.26774997],
#  ['five', 'month', '3.38', 0.23675838],
#  ['report', 'gain', '3.63', 0.5648403],
#  ['investor', 'earning', '7.13', 0.0],
#  ['liquid', 'water', '7.89', 0.49456447],
#  ['baseball', 'season', '5.97', 0.0],
#  ['game', 'victory', '7.03', 0.38714615],
#  ['game', 'team', '7.69', 0.5244312],
#  ['marathon', 'sprint', '7.47', 0.23487042],
#  ['game', 'series', '6.19', 0.27847794],
#  ['game', 'defeat', '6.97', 0.33804953],
#  ['seven', 'series', '3.56', 0.27913532],
#  ['seafood', 'sea', '7.47', 0.0],
#  ['seafood', 'food', '8.34', 0.0],
#  ['seafood', 'lobster', '8.70', 0.0],
#  ['lobster', 'food', '7.81', 0.2525954],
#  ['lobster', 'wine', '5.70', 0.3363375],
#  ['food', 'preparation', '6.22', 0.52303195],
#  ['video', 'archive', '6.34', 0.5682785],
#  ['start', 'year', '4.06', 0.5120761],
#  ['start', 'match', '4.47', 0.48920903],
#  ['game', 'round', '5.97', 0.44679797],
#  ['boxing', 'round', '7.61', 0.27097017],
#  ['championship', 'tournament', '8.36', 0.70638585],
#  ['fighting', 'defeating', '7.41', 0.0],
#  ['line', 'insurance', '2.69', 0.33403355],
#  ['day', 'summer', '3.94', 0.4460059],
#  ['summer', 'drought', '7.16', 0.34604123],
#  ['summer', 'nature', '5.63', 0.18090566],
#  ['day', 'dawn', '7.53', 0.37942904],
#  ['nature', 'environment', '8.31', 0.33210677],
#  ['environment', 'ecology', '8.81', 0.25462544],
#  ['nature', 'man', '6.25', 0.35381696],
#  ['man', 'woman', '8.30', 0.43476725],
#  ['man', 'governor', '5.25', 0.35854873],
#  ['murder', 'manslaughter', '8.53', 0.0],
#  ['soap', 'opera', '7.94', 0.0603857],
#  ['opera', 'performance', '6.88', 0.44061223],
#  ['life', 'lesson', '5.94', 0.36700344],
#  ['focus', 'life', '4.06', 0.27295408],
#  ['production', 'crew', '6.25', 0.22261837],
#  ['television', 'film', '7.72', 0.57855564],
#  ['lover', 'quarrel', '6.19', 0.18891577],
#  ['viewer', 'serial', '2.97', 0.08555553],
#  ['possibility', 'girl', '1.94', 0.38126755],
#  ['population', 'development', '3.75', 0.24342453],
#  ['morality', 'importance', '3.31', 0.23594514],
#  ['morality', 'marriage', '3.69', 0.2580388],
#  ['Mexico', 'Brazil', '7.44', 0.0],
#  ['gender', 'equality', '6.41', 0.5037996],
#  ['change', 'attitude', '5.44', 0.35322797],
#  ['family', 'planning', '6.25', 0.27648613],
#  ['opera', 'industry', '2.63', 0.36698684],
#  ['sugar', 'approach', '0.88', 0.18015389],
#  ['practice', 'institution', '3.19', 0.39839554],
#  ['ministry', 'culture', '4.69', 0.0],
#  ['problem', 'challenge', '6.75', 0.5959656],
#  ['size', 'prominence', '5.31', 0.23719269],
#  ['country', 'citizen', '7.31', 0.37776527],
#  ['planet', 'people', '5.75', 0.35534233],
#  ['development', 'issue', '3.97', 0.38396418],
#  ['experience', 'music', '3.47', 0.20160502],
#  ['music', 'project', '3.63', 0.4768666],
#  ['glass', 'metal', '5.56', 0.5881498],
#  ['aluminum', 'metal', '7.83', 0.6444408],
#  ['chance', 'credibility', '3.88', 0.3408285],
#  ['exhibit', 'memorabilia', '5.31', 0.0],
#  ['concert', 'virtuoso', '6.81', 0.17649353],
#  ['rock', 'jazz', '7.59', 0.14225388],
#  ['museum', 'theater', '7.19', 0.42030132],
#  ['observation', 'architecture', '4.38', 0.16502546],
#  ['space', 'world', '6.53', 0.34786636],
#  ['preservation', 'world', '6.19', 0.36223802],
#  ['admission', 'ticket', '7.69', 0.8624645],
#  ['shower', 'thunderstorm', '6.31', 0.0],
#  ['shower', 'flood', '6.03', 0.38901687],
#  ['weather', 'forecast', '8.34', 0.18531038],
#  ['disaster', 'area', '6.25', 0.32084703],
#  ['governor', 'office', '6.34', 0.4131596],
#  ['architecture', 'century', '3.78', 0.17853424]]

# %%
model.wv.vocab
# Out:
# {'ebbene': <gensim.models.keyedvectors.Vocab at 0x1e1bdb775c0>,
#  'credere_bn:00083369v': <gensim.models.keyedvectors.Vocab at 0x1e1c805da20>,
#  'estremamente_bn:00115271r': <gensim.models.keyedvectors.Vocab at 0x1e1c8600e80>,
#  'importante_bn:00104681a': <gensim.models.keyedvectors.Vocab at 0x1e1c8600e10>,
#  'ridurre_bn:00086418v': <gensim.models.keyedvectors.Vocab at 0x1e1c8600c88>,
#  'zona_bn:00005513n': <gensim.models.keyedvectors.Vocab at 0x1e1c8063b00>,
#  'grigio_bn:00103765a': <gensim.models.keyedvectors.Vocab at 0x1e1c80639b0>,
#  'accentuare_bn:00082195v': <gensim.models.keyedvectors.Vocab at 0x1e1c80639e8>,
#  'momento_bn:00055597n': <gensim.models.keyedvectors.Vocab at 0x1e1c8063a20>,
#  'collaborazione_bn:00022452n': <gensim.models.keyedvectors.Vocab at 0x1e1c8063208>,
#  'infine_bn:00114417r': <gensim.models.keyedvectors.Vocab at 0x1e1c80631d0>,
#  'signore_bn:00035925n': <gensim.models.keyedvectors.Vocab at 0x1e1c80632b0>,
#  'presidente_bn:00064234n': <gensim.models.keyedvectors.Vocab at 0x1e1c8063748>,
#  '\\xc3\\xa8': <gensim.models.keyedvectors.Vocab at 0x1e1c8063780>,
#  'parlare_bn:00090943v': <gensim.models.keyedvectors.Vocab at 0x1e1c8063898>,
#  'fare_bn:00082285v': <gensim.models.keyedvectors.Vocab at 0x1e1c8063390>,
#  'santer': <gensim.models.keyedvectors.Vocab at 0x1e1c8063128>,
#  'ridefinizione_bn:00066711n': <gensim.models.keyedvectors.Vocab at 0x1e1c80636d8>,
#  'progetto_bn:00049573n': <gensim.models.keyedvectors.Vocab at 0x1e1c8063240>,
#  'politico_bn:00108760a': <gensim.models.keyedvectors.Vocab at 0x1e1c8063160>,
#  'istituzionale_bn:00105210a': <gensim.models.keyedvectors.Vocab at 0x1e1c8063470>,
#  'd&apos;': <gensim.models.keyedvectors.Vocab at 0x1e1c8063518>,
#  'accordo_bn:00002089n': <gensim.models.keyedvectors.Vocab at 0x1e1c8063a90>,
#  'formulazione_bn:00021553n': <gensim.models.keyedvectors.Vocab at 0x1e1c8063588>,
#  'c&apos;': <gensim.models.keyedvectors.Vocab at 0x1e1c8063b70>,
#  'bisogno_bn:00026107n': <gensim.models.keyedvectors.Vocab at 0x1e1c8063a58>,
#  'insieme': <gensim.models.keyedvectors.Vocab at 0x1e1c80632e8>,
#  'pi\\xc3\\xb9_bn:00116284r': <gensim.models.keyedvectors.Vocab at 0x1e1c8063198>,
#  'europa': <gensim.models.keyedvectors.Vocab at 0x1e1c8063ac8>,
#  'meno': <gensim.models.keyedvectors.Vocab at 0x1e1c8063978>,
#  'avviso_bn:00007498n': <gensim.models.keyedvectors.Vocab at 0x1e1c8063940>,
#  'altres\\xc3\\xac': <gensim.models.keyedvectors.Vocab at 0x1e1c8063710>,
#  'un&apos;': <gensim.models.keyedvectors.Vocab at 0x1e1c8063860>,
#  'esempio_bn:00032100n': <gensim.models.keyedvectors.Vocab at 0x1e1c80637f0>,
#  'politica': <gensim.models.keyedvectors.Vocab at 0x1e1c80634a8>,
#  'estera': <gensim.models.keyedvectors.Vocab at 0x1e1c8063358>,
#  'necessario_bn:00107182a': <gensim.models.keyedvectors.Vocab at 0x1e1c8063ba8>,
#  'istituzione_bn:00046954n': <gensim.models.keyedvectors.Vocab at 0x1e1c8063be0>,
#  'adeguato_bn:00096449a': <gensim.models.keyedvectors.Vocab at 0x1e1c8063c18>,
#  'l&apos;': <gensim.models.keyedvectors.Vocab at 0x1e1c8063c50>,
#  'occupazione_bn:00030616n': <gensim.models.keyedvectors.Vocab at 0x1e1c8063c88>,
#  'occorrere_bn:00091131v': <gensim.models.keyedvectors.Vocab at 0x1e1c8063cc0>,
#  'avere': <gensim.models.keyedvectors.Vocab at 0x1e1c8063cf8>,
#  'possibilit\\xc3\\xa0_bn:00045632n': <gensim.models.keyedvectors.Vocab at 0x1e1c8063d30>,
#  'adottare_bn:00082379v': <gensim.models.keyedvectors.Vocab at 0x1e1c8063d68>,
#  'decisione_bn:00025693n': <gensim.models.keyedvectors.Vocab at 0x1e1c8063da0>,
#  'livello_bn:00025965n': <gensim.models.keyedvectors.Vocab at 0x1e1c8063dd8>,
#  'europeo_bn:00102440a': <gensim.models.keyedvectors.Vocab at 0x1e1c8063e10>,
#  'pi\\xc3\\xb9_bn:00114171r': <gensim.models.keyedvectors.Vocab at 0x1e1c8063e48>,
#  'delega': <gensim.models.keyedvectors.Vocab at 0x1e1c8063e80>,
#  'nell&apos;': <gensim.models.keyedvectors.Vocab at 0x1e1c8063eb8>,
#  'applicazione_bn:00036821n': <gensim.models.keyedvectors.Vocab at 0x1e1c8063ef0>,
#  'proprio': <gensim.models.keyedvectors.Vocab at 0x1e1c8063f28>,
#  'creare_bn:00086008v': <gensim.models.keyedvectors.Vocab at 0x1e1c8063f60>,
#  'nuovo_bn:00107267a': <gensim.models.keyedvectors.Vocab at 0x1e1c8063f98>,
#  'equilibrio_bn:00031312n': <gensim.models.keyedvectors.Vocab at 0x1e1c8063fd0>,
#  'fra': <gensim.models.keyedvectors.Vocab at 0x1e1c806f048>,
#  'stato_bn:00003341n': <gensim.models.keyedvectors.Vocab at 0x1e1c806f080>,
#  'unione_bn:00050409n': <gensim.models.keyedvectors.Vocab at 0x1e1c806f0b8>,
#  'perch\\xc3\\xa9': <gensim.models.keyedvectors.Vocab at 0x1e1c806f0f0>,
#  'costituire_bn:00082715v': <gensim.models.keyedvectors.Vocab at 0x1e1c806f128>,
#  'reale_bn:00096397a': <gensim.models.keyedvectors.Vocab at 0x1e1c806f160>,
#  'problema_bn:00048242n': <gensim.models.keyedvectors.Vocab at 0x1e1c806f198>,
#  'volere_bn:00082822v': <gensim.models.keyedvectors.Vocab at 0x1e1c806f1d0>,
#  'quindi': <gensim.models.keyedvectors.Vocab at 0x1e1c806f208>,
#  'gestione_bn:00053116n': <gensim.models.keyedvectors.Vocab at 0x1e1c806f240>,
#  'particolaristico_bn:00108300a': <gensim.models.keyedvectors.Vocab at 0x1e1c806f278>,
#  'tutte': <gensim.models.keyedvectors.Vocab at 0x1e1c806f2b0>,
#  'dovere_bn:00091362v': <gensim.models.keyedvectors.Vocab at 0x1e1c806f2e8>,
#  'essere': <gensim.models.keyedvectors.Vocab at 0x1e1c806f320>,
#  'democratico_bn:00101149a': <gensim.models.keyedvectors.Vocab at 0x1e1c806f358>,
#  'efficace_bn:00102038a': <gensim.models.keyedvectors.Vocab at 0x1e1c806f390>,
#  'caso_bn:00016403n': <gensim.models.keyedvectors.Vocab at 0x1e1c806f3c8>,
#  'insistere_bn:00089192v': <gensim.models.keyedvectors.Vocab at 0x1e1c806f400>,
#  'proporzionalit\\xc3\\xa0_bn:00064775n': <gensim.models.keyedvectors.Vocab at 0x1e1c806f438>,
#  'infine_bn:00115252r': <gensim.models.keyedvectors.Vocab at 0x1e1c806f470>,
#  'volere_bn:00095802v': <gensim.models.keyedvectors.Vocab at 0x1e1c806f4a8>,
#  'dire_bn:00093287v': <gensim.models.keyedvectors.Vocab at 0x1e1c806f4e0>,
#  'alcune': <gensim.models.keyedvectors.Vocab at 0x1e1c806f518>,
#  'cosa_bn:00074798n': <gensim.models.keyedvectors.Vocab at 0x1e1c806f550>,
#  'possono': <gensim.models.keyedvectors.Vocab at 0x1e1c806f588>,
#  'fare_bn:00088736v': <gensim.models.keyedvectors.Vocab at 0x1e1c806f5c0>,
#  'senza': <gensim.models.keyedvectors.Vocab at 0x1e1c806f5f8>,
#  'modifica_bn:00001410n': <gensim.models.keyedvectors.Vocab at 0x1e1c806f630>,
#  'trattato_bn:00000728n': <gensim.models.keyedvectors.Vocab at 0x1e1c806f668>,
#  'altre': <gensim.models.keyedvectors.Vocab at 0x1e1c806f6a0>,
#  'no_bn:00116360r': <gensim.models.keyedvectors.Vocab at 0x1e1c806f6d8>,
#  'modifica_bn:00003125n': <gensim.models.keyedvectors.Vocab at 0x1e1c806f710>,
#  'implicare_bn:00085636v': <gensim.models.keyedvectors.Vocab at 0x1e1c806f748>,
#  'metodo_bn:00061229n': <gensim.models.keyedvectors.Vocab at 0x1e1c806f780>,
#  'revisione_bn:00067275n': <gensim.models.keyedvectors.Vocab at 0x1e1c806f7b8>,
#  'sperare_bn:00088954v': <gensim.models.keyedvectors.Vocab at 0x1e1c806f7f0>,
#  'combattere_bn:00085711v': <gensim.models.keyedvectors.Vocab at 0x1e1c806f828>,
#  'tal': <gensim.models.keyedvectors.Vocab at 0x1e1c806f860>,
#  'senso_bn:00046139n': <gensim.models.keyedvectors.Vocab at 0x1e1c806f898>,
#  'commissione': <gensim.models.keyedvectors.Vocab at 0x1e1c806f8d0>,
#  'prendere_bn:00082276v': <gensim.models.keyedvectors.Vocab at 0x1e1c806f908>,
#  'dopo': <gensim.models.keyedvectors.Vocab at 0x1e1c806f940>,
#  'ratifica_bn:00021758n': <gensim.models.keyedvectors.Vocab at 0x1e1c806f978>,
#  'amsterdam': <gensim.models.keyedvectors.Vocab at 0x1e1c806f9b0>,
#  'iniziativa': <gensim.models.keyedvectors.Vocab at 0x1e1c806f9e8>,
#  'concertazione': <gensim.models.keyedvectors.Vocab at 0x1e1c806fa20>,
#  'diverse': <gensim.models.keyedvectors.Vocab at 0x1e1c806fa58>,
#  'signora_bn:00001530n': <gensim.models.keyedvectors.Vocab at 0x1e1c806fa90>,
#  'presidente_bn:00018323n': <gensim.models.keyedvectors.Vocab at 0x1e1c806fac8>,
#  'discutere_bn:00086942v': <gensim.models.keyedvectors.Vocab at 0x1e1c806fb00>,
#  'stato': <gensim.models.keyedvectors.Vocab at 0x1e1c806fb38>,
#  'dell&apos;': <gensim.models.keyedvectors.Vocab at 0x1e1c806fb70>,
#  'unione_bn:00058032n': <gensim.models.keyedvectors.Vocab at 0x1e1c806fba8>,
#  'opportuno_bn:00107924a': <gensim.models.keyedvectors.Vocab at 0x1e1c806fbe0>,
#  'puntualizzare': <gensim.models.keyedvectors.Vocab at 0x1e1c806fc18>,
#  'paragone_bn:00003787n': <gensim.models.keyedvectors.Vocab at 0x1e1c806fc50>,
#  'gi\\xc3\\xa0': <gensim.models.keyedvectors.Vocab at 0x1e1c806fc88>,
#  'proporre_bn:00090584v': <gensim.models.keyedvectors.Vocab at 0x1e1c806fcc0>,
#  'cattedrale_bn:00016759n': <gensim.models.keyedvectors.Vocab at 0x1e1c806fcf8>,
#  'gotica': <gensim.models.keyedvectors.Vocab at 0x1e1c806fd30>,
#  'credere_bn:00083370v': <gensim.models.keyedvectors.Vocab at 0x1e1c806fd68>,
#  'momento_bn:00055604n': <gensim.models.keyedvectors.Vocab at 0x1e1c806fda0>,
#  'unione': <gensim.models.keyedvectors.Vocab at 0x1e1c806fdd8>,
#  'europea': <gensim.models.keyedvectors.Vocab at 0x1e1c806fe10>,
#  'effettivamente_bn:00114357r': <gensim.models.keyedvectors.Vocab at 0x1e1c806fe48>,
#  'cattedrale': <gensim.models.keyedvectors.Vocab at 0x1e1c806fe80>,
#  'met\\xc3\\xa0_bn:00054842n': <gensim.models.keyedvectors.Vocab at 0x1e1c806feb8>,
#  'costruzione_bn:00013722n': <gensim.models.keyedvectors.Vocab at 0x1e1c806fef0>,
#  'pilastro_bn:00020827n': <gensim.models.keyedvectors.Vocab at 0x1e1c806ff28>,
#  'per\\xc3\\xb2_bn:00114216r': <gensim.models.keyedvectors.Vocab at 0x1e1c806ff60>,
#  'poggiare_bn:00092906v': <gensim.models.keyedvectors.Vocab at 0x1e1c806ff98>,
#  'niente': <gensim.models.keyedvectors.Vocab at 0x1e1c806ffd0>,
#  'costruire_bn:00085678v': <gensim.models.keyedvectors.Vocab at 0x1e1c8071048>,
#  'passerella_bn:00060863n': <gensim.models.keyedvectors.Vocab at 0x1e1c8071080>,
#  'portare_bn:00084555v': <gensim.models.keyedvectors.Vocab at 0x1e1c80710b8>,
#  'nessuna': <gensim.models.keyedvectors.Vocab at 0x1e1c80710f0>,
#  'parte': <gensim.models.keyedvectors.Vocab at 0x1e1c8071128>,
#  'disporre_bn:00082777v': <gensim.models.keyedvectors.Vocab at 0x1e1c8071160>,
#  'persino': <gensim.models.keyedvectors.Vocab at 0x1e1c8071198>,
#  'spazio_bn:00046665n': <gensim.models.keyedvectors.Vocab at 0x1e1c80711d0>,
#  'coprire_bn:00085913v': <gensim.models.keyedvectors.Vocab at 0x1e1c8071208>,
#  'nessun': <gensim.models.keyedvectors.Vocab at 0x1e1c8071240>,
#  'fondo_bn:00008782n': <gensim.models.keyedvectors.Vocab at 0x1e1c8071278>,
#  'comunitario': <gensim.models.keyedvectors.Vocab at 0x1e1c80712b0>,
#  'suole': <gensim.models.keyedvectors.Vocab at 0x1e1c80712e8>,
#  'dire': <gensim.models.keyedvectors.Vocab at 0x1e1c8071320>,
#  'crescere_bn:00089666v': <gensim.models.keyedvectors.Vocab at 0x1e1c8071358>,
#  'momento_bn:00060969n': <gensim.models.keyedvectors.Vocab at 0x1e1c8071390>,
#  'crisi_bn:00023844n': <gensim.models.keyedvectors.Vocab at 0x1e1c80713c8>,
#  'ovvero': <gensim.models.keyedvectors.Vocab at 0x1e1c8071400>,
#  'procedere_bn:00085715v': <gensim.models.keyedvectors.Vocab at 0x1e1c8071438>,
#  'molto': <gensim.models.keyedvectors.Vocab at 0x1e1c8071470>,
#  'lentamente_bn:00115161r': <gensim.models.keyedvectors.Vocab at 0x1e1c80714a8>,
#  'periodo_bn:00061605n': <gensim.models.keyedvectors.Vocab at 0x1e1c80714e0>,
#  'normale_bn:00113459a': <gensim.models.keyedvectors.Vocab at 0x1e1c8071518>,
#  'mentre': <gensim.models.keyedvectors.Vocab at 0x1e1c8071550>,
#  'situazione_bn:00071869n': <gensim.models.keyedvectors.Vocab at 0x1e1c8071588>,
#  'accelerare_bn:00082193v': <gensim.models.keyedvectors.Vocab at 0x1e1c80715c0>,
#  'rafforzare_bn:00085493v': <gensim.models.keyedvectors.Vocab at 0x1e1c80715f8>,
#  'propria': <gensim.models.keyedvectors.Vocab at 0x1e1c8071630>,
#  'azione_bn:00001127n': <gensim.models.keyedvectors.Vocab at 0x1e1c8071668>,
#  'diversi': <gensim.models.keyedvectors.Vocab at 0x1e1c80716a0>,
#  'intervento_bn:00047092n': <gensim.models.keyedvectors.Vocab at 0x1e1c80716d8>,
#  'rispettivamente': <gensim.models.keyedvectors.Vocab at 0x1e1c8071710>,
#  'parlamento_bn:00060708n': <gensim.models.keyedvectors.Vocab at 0x1e1c8071748>,
#  'consiglio': <gensim.models.keyedvectors.Vocab at 0x1e1c8071780>,
#  'commissione_bn:00021015n': <gensim.models.keyedvectors.Vocab at 0x1e1c80717b8>,
#  'mettere_bn:00088736v': <gensim.models.keyedvectors.Vocab at 0x1e1c80717f0>,
#  'evidenza_bn:00032045n': <gensim.models.keyedvectors.Vocab at 0x1e1c8071828>,
#  'struttura_bn:00035909n': <gensim.models.keyedvectors.Vocab at 0x1e1c8071860>,
#  'costruire_bn:00087714v': <gensim.models.keyedvectors.Vocab at 0x1e1c8071898>,
#  'finalit\\xc3\\xa0_bn:00002179n': <gensim.models.keyedvectors.Vocab at 0x1e1c80718d0>,
#  'euro_bn:00031888n': <gensim.models.keyedvectors.Vocab at 0x1e1c8071908>,
#  'consentire_bn:00082371v': <gensim.models.keyedvectors.Vocab at 0x1e1c8071940>,
#  'resistere_bn:00089411v': <gensim.models.keyedvectors.Vocab at 0x1e1c8071978>,
#  'finanziario_bn:00102971a': <gensim.models.keyedvectors.Vocab at 0x1e1c80719b0>,
#  'internazionale_bn:00102626a': <gensim.models.keyedvectors.Vocab at 0x1e1c80719e8>,
#  'grande': <gensim.models.keyedvectors.Vocab at 0x1e1c8071a20>,
#  'problema_bn:00064527n': <gensim.models.keyedvectors.Vocab at 0x1e1c8071a58>,
#  'comunit\\xc3\\xa0_bn:00021248n': <gensim.models.keyedvectors.Vocab at 0x1e1c8071a90>,
#  'buono_bn:00103672a': <gensim.models.keyedvectors.Vocab at 0x1e1c8071ac8>,
#  'stata': <gensim.models.keyedvectors.Vocab at 0x1e1c8071b00>,
#  'ancora': <gensim.models.keyedvectors.Vocab at 0x1e1c8071b38>,
#  'terminare_bn:00087608v': <gensim.models.keyedvectors.Vocab at 0x1e1c8071b70>,
#  'almeno_bn:00114406r': <gensim.models.keyedvectors.Vocab at 0x1e1c8071ba8>,
#  'due_bn:00095950a': <gensim.models.keyedvectors.Vocab at 0x1e1c8071be0>,
#  'tre_bn:00095975a': <gensim.models.keyedvectors.Vocab at 0x1e1c8071c18>,
#  'generazione_bn:00037676n': <gensim.models.keyedvectors.Vocab at 0x1e1c8071c50>,
#  'ora': <gensim.models.keyedvectors.Vocab at 0x1e1c8071c88>,
#  'trovare_bn:00085393v': <gensim.models.keyedvectors.Vocab at 0x1e1c8071cc0>,
#  'necessit\\xc3\\xa0_bn:00026107n': <gensim.models.keyedvectors.Vocab at 0x1e1c8071cf8>,
#  'ingrandire_bn:00084121v': <gensim.models.keyedvectors.Vocab at 0x1e1c8071d30>,
#  'iniziare_bn:00083341v': <gensim.models.keyedvectors.Vocab at 0x1e1c8071d68>,
#  'spesso': <gensim.models.keyedvectors.Vocab at 0x1e1c8071da0>,
#  'partire_bn:00086600v': <gensim.models.keyedvectors.Vocab at 0x1e1c8071dd8>,
#  'piccolo_bn:00106058a': <gensim.models.keyedvectors.Vocab at 0x1e1c8071e10>,
#  'chiesa_bn:00018995n': <gensim.models.keyedvectors.Vocab at 0x1e1c8071e48>,
#  'venire_bn:00085320v': <gensim.models.keyedvectors.Vocab at 0x1e1c8071e80>,
#  'poi': <gensim.models.keyedvectors.Vocab at 0x1e1c8071eb8>,
#  'ampliare_bn:00084121v': <gensim.models.keyedvectors.Vocab at 0x1e1c8071ef0>,
#  'fino': <gensim.models.keyedvectors.Vocab at 0x1e1c8071f28>,
#  'coprire_bn:00085720v': <gensim.models.keyedvectors.Vocab at 0x1e1c8071f60>,
#  'intero': <gensim.models.keyedvectors.Vocab at 0x1e1c8071f98>,
#  'antico_bn:00097066a': <gensim.models.keyedvectors.Vocab at 0x1e1c8071fd0>,
#  'citt\\xc3\\xa0': <gensim.models.keyedvectors.Vocab at 0x1e1c8075048>,
#  'avvenire_bn:00085337v': <gensim.models.keyedvectors.Vocab at 0x1e1c8075080>,
#  'vienna': <gensim.models.keyedvectors.Vocab at 0x1e1c80750b8>,
#  'momento_bn:00046942n': <gensim.models.keyedvectors.Vocab at 0x1e1c80750f0>,
#  'dovere_bn:00089244v': <gensim.models.keyedvectors.Vocab at 0x1e1c8075128>,
#  'ingrandire_bn:00087649v': <gensim.models.keyedvectors.Vocab at 0x1e1c8075160>,
#  'fare_bn:00082276v': <gensim.models.keyedvectors.Vocab at 0x1e1c8075198>,
#  'entrare_bn:00088013v': <gensim.models.keyedvectors.Vocab at 0x1e1c80751d0>,
#  'paese_bn:00023236n': <gensim.models.keyedvectors.Vocab at 0x1e1c8075208>,
#  'baltico': <gensim.models.keyedvectors.Vocab at 0x1e1c8075240>,
#  'mediterraneo': <gensim.models.keyedvectors.Vocab at 0x1e1c8075278>,
#  'cento_bn:00095890a': <gensim.models.keyedvectors.Vocab at 0x1e1c80752b0>,
#  'milioni': <gensim.models.keyedvectors.Vocab at 0x1e1c80752e8>,
#  'persona_bn:00046516n': <gensim.models.keyedvectors.Vocab at 0x1e1c8075320>,
#  'diritto_bn:00048655n': <gensim.models.keyedvectors.Vocab at 0x1e1c8075358>,
#  'stare_bn:00087441v': <gensim.models.keyedvectors.Vocab at 0x1e1c8075390>,
#  'qui': <gensim.models.keyedvectors.Vocab at 0x1e1c80753c8>,
#  'modo_bn:00033729n': <gensim.models.keyedvectors.Vocab at 0x1e1c8075400>,
#  'utilizzare_bn:00082705v': <gensim.models.keyedvectors.Vocab at 0x1e1c8075438>,
#  'espressione_bn:00062115n': <gensim.models.keyedvectors.Vocab at 0x1e1c8075470>,
#  'tedesco_bn:00103560a': <gensim.models.keyedvectors.Vocab at 0x1e1c80754a8>,
#  'venire_bn:00083193v': <gensim.models.keyedvectors.Vocab at 0x1e1c80754e0>,
#  'tradurre_bn:00089840v': <gensim.models.keyedvectors.Vocab at 0x1e1c8075518>,
#  'spagnolo_bn:00073092n': <gensim.models.keyedvectors.Vocab at 0x1e1c8075550>,
#  'finire_bn:00087608v': <gensim.models.keyedvectors.Vocab at 0x1e1c8075588>,
#  'gettare_bn:00084627v': <gensim.models.keyedvectors.Vocab at 0x1e1c80755c0>,
#  'via': <gensim.models.keyedvectors.Vocab at 0x1e1c80755f8>,
#  'bambino_bn:00018346n': <gensim.models.keyedvectors.Vocab at 0x1e1c8075630>,
#  'acqua_bn:00042379n': <gensim.models.keyedvectors.Vocab at 0x1e1c8075668>,
#  'bagno_bn:00009011n': <gensim.models.keyedvectors.Vocab at 0x1e1c80756a0>,
#  'verit\\xc3\\xa0_bn:00072816n': <gensim.models.keyedvectors.Vocab at 0x1e1c80756d8>,
#  'presidente': <gensim.models.keyedvectors.Vocab at 0x1e1c8075710>,
#  'continuare_bn:00085714v': <gensim.models.keyedvectors.Vocab at 0x1e1c8075748>,
#  'andare': <gensim.models.keyedvectors.Vocab at 0x1e1c8075780>,
#  'avanti': <gensim.models.keyedvectors.Vocab at 0x1e1c80757b8>,
#  'cos\\xc3\\xac_bn:00117263r': <gensim.models.keyedvectors.Vocab at 0x1e1c80757f0>,
#  'fine_bn:00030719n': <gensim.models.keyedvectors.Vocab at 0x1e1c8075828>,
#  'n\\xc3\\xa9': <gensim.models.keyedvectors.Vocab at 0x1e1c8075860>,
#  'altro': <gensim.models.keyedvectors.Vocab at 0x1e1c8075898>,
#  'luogo_bn:00062699n': <gensim.models.keyedvectors.Vocab at 0x1e1c80758d0>,
#  'riporre_bn:00089368v': <gensim.models.keyedvectors.Vocab at 0x1e1c8075908>,
#  'cosa_bn:00076929n': <gensim.models.keyedvectors.Vocab at 0x1e1c8075940>,
#  'frazione_bn:00042729n': <gensim.models.keyedvectors.Vocab at 0x1e1c8075978>,
#  'infinitesimali': <gensim.models.keyedvectors.Vocab at 0x1e1c80759b0>,
#  'bilancio_bn:00013640n': <gensim.models.keyedvectors.Vocab at 0x1e1c80759e8>,
#  'porto_bn:00063640n': <gensim.models.keyedvectors.Vocab at 0x1e1c8075a20>,
#  'nazionale_bn:00107138a': <gensim.models.keyedvectors.Vocab at 0x1e1c8075a58>,
#  'divenire_bn:00083293v': <gensim.models.keyedvectors.Vocab at 0x1e1c8075a90>,
#  'quali': <gensim.models.keyedvectors.Vocab at 0x1e1c8075ac8>,
#  'sostenere_bn:00094612v': <gensim.models.keyedvectors.Vocab at 0x1e1c8075b00>,
#  'contribuire_bn:00084904v': <gensim.models.keyedvectors.Vocab at 0x1e1c8075b38>,
#  'eccessivamente_bn:00115274r': <gensim.models.keyedvectors.Vocab at 0x1e1c8075b70>,
#  'presidente_bn:00048488n': <gensim.models.keyedvectors.Vocab at 0x1e1c8075ba8>,
#  'credere_bn:00084334v': <gensim.models.keyedvectors.Vocab at 0x1e1c8075be0>,
#  'portare': <gensim.models.keyedvectors.Vocab at 0x1e1c8075c18>,
#  'grande_bn:00098342a': <gensim.models.keyedvectors.Vocab at 0x1e1c8075c50>,
#  'progetto_bn:00062759n': <gensim.models.keyedvectors.Vocab at 0x1e1c8075c88>,
#  'costruire_bn:00084198v': <gensim.models.keyedvectors.Vocab at 0x1e1c8075cc0>,
#  'vero_bn:00102543a': <gensim.models.keyedvectors.Vocab at 0x1e1c8075cf8>,
#  'casa_bn:00044994n': <gensim.models.keyedvectors.Vocab at 0x1e1c8075d30>,
#  'intera': <gensim.models.keyedvectors.Vocab at 0x1e1c8075d68>,
#  'consiglio_bn:00014446n': <gensim.models.keyedvectors.Vocab at 0x1e1c8075da0>,
#  'nome': <gensim.models.keyedvectors.Vocab at 0x1e1c8075dd8>,
#  'gruppo_bn:00072536n': <gensim.models.keyedvectors.Vocab at 0x1e1c8075e10>,
#  'porgere_bn:00088825v': <gensim.models.keyedvectors.Vocab at 0x1e1c8075e48>,
#  'caloroso_bn:00096597a': <gensim.models.keyedvectors.Vocab at 0x1e1c8075e80>,
#  'benvenuto_bn:00080852n': <gensim.models.keyedvectors.Vocab at 0x1e1c8075eb8>,
#  'oggi_bn:00117315r': <gensim.models.keyedvectors.Vocab at 0x1e1c8075ef0>,
#  'primo_bn:00101937a': <gensim.models.keyedvectors.Vocab at 0x1e1c8075f28>,
#  'volta': <gensim.models.keyedvectors.Vocab at 0x1e1c8075f60>,
#  'prendere_bn:00087576v': <gensim.models.keyedvectors.Vocab at 0x1e1c8075f98>,
#  'parola_bn:00081546n': <gensim.models.keyedvectors.Vocab at 0x1e1c8075fd0>,
#  'fronte_bn:00032598n': <gensim.models.keyedvectors.Vocab at 0x1e1c8078048>,
#  'volere_bn:00086682v': <gensim.models.keyedvectors.Vocab at 0x1e1c8078080>,
#  'ringraziare_bn:00088854v': <gensim.models.keyedvectors.Vocab at 0x1e1c80780b8>,
#  'omaggio_bn:00051029n': <gensim.models.keyedvectors.Vocab at 0x1e1c80780f0>,
#  'rendere_bn:00086008v': <gensim.models.keyedvectors.Vocab at 0x1e1c8078128>,
#  'all&apos;': <gensim.models.keyedvectors.Vocab at 0x1e1c8078160>,
#  'opera_bn:00051538n': <gensim.models.keyedvectors.Vocab at 0x1e1c8078198>,
#  'portata_bn:00003268n': <gensim.models.keyedvectors.Vocab at 0x1e1c80781d0>,
#  'storico_bn:00104221a': <gensim.models.keyedvectors.Vocab at 0x1e1c8078208>,
#  'compiere_bn:00082225v': <gensim.models.keyedvectors.Vocab at 0x1e1c8078240>,
#  'cancelliere': <gensim.models.keyedvectors.Vocab at 0x1e1c8078278>,
#  'federale_bn:00102871a': <gensim.models.keyedvectors.Vocab at 0x1e1c80782b0>,
#  'kohl': <gensim.models.keyedvectors.Vocab at 0x1e1c80782e8>,
#  'discussione_bn:00005599n': <gensim.models.keyedvectors.Vocab at 0x1e1c8078320>,
#  'svolgere_bn:00086942v': <gensim.models.keyedvectors.Vocab at 0x1e1c8078358>,
#  'clima_bn:00019780n': <gensim.models.keyedvectors.Vocab at 0x1e1c8078390>,
#  'segnare_bn:00092430v': <gensim.models.keyedvectors.Vocab at 0x1e1c80783c8>,
#  'dall&apos;': <gensim.models.keyedvectors.Vocab at 0x1e1c8078400>,
#  'incertezza_bn:00028425n': <gensim.models.keyedvectors.Vocab at 0x1e1c8078438>,
#  'mondializzazione': <gensim.models.keyedvectors.Vocab at 0x1e1c8078470>,
#  'globalizzazione_bn:00040682n': <gensim.models.keyedvectors.Vocab at 0x1e1c80784a8>,
#  'generare_bn:00083336v': <gensim.models.keyedvectors.Vocab at 0x1e1c80784e0>,
#  'inquietudine_bn:00078425n': <gensim.models.keyedvectors.Vocab at 0x1e1c8078518>,
#  'turbolenza_bn:00078625n': <gensim.models.keyedvectors.Vocab at 0x1e1c8078550>,
#  'dapprima_bn:00114055r': <gensim.models.keyedvectors.Vocab at 0x1e1c8078588>,
#  'asia': <gensim.models.keyedvectors.Vocab at 0x1e1c80785c0>,
#  'sudorientale': <gensim.models.keyedvectors.Vocab at 0x1e1c80785f8>,
#  'giappone': <gensim.models.keyedvectors.Vocab at 0x1e1c8078630>,
#  'america': <gensim.models.keyedvectors.Vocab at 0x1e1c8078668>,
#  'latino_bn:00105766a': <gensim.models.keyedvectors.Vocab at 0x1e1c80786a0>,
#  'russia': <gensim.models.keyedvectors.Vocab at 0x1e1c80786d8>,
#  'infine_bn:00115368r': <gensim.models.keyedvectors.Vocab at 0x1e1c8078710>,
#  'borsa_bn:00070218n': <gensim.models.keyedvectors.Vocab at 0x1e1c8078748>,
#  'stati': <gensim.models.keyedvectors.Vocab at 0x1e1c8078780>,
#  'uniti': <gensim.models.keyedvectors.Vocab at 0x1e1c80787b8>,
#  'dare_bn:00087156v': <gensim.models.keyedvectors.Vocab at 0x1e1c80787f0>,
#  'impressione_bn:00064453n': <gensim.models.keyedvectors.Vocab at 0x1e1c8078828>,
#  'economia_bn:00029676n': <gensim.models.keyedvectors.Vocab at 0x1e1c8078860>,
#  'mondiale_bn:00103624a': <gensim.models.keyedvectors.Vocab at 0x1e1c8078898>,
#  'privo_bn:00098082a': <gensim.models.keyedvectors.Vocab at 0x1e1c80788d0>,
#  'qualsiasi': <gensim.models.keyedvectors.Vocab at 0x1e1c8078908>,
#  'guida_bn:00042102n': <gensim.models.keyedvectors.Vocab at 0x1e1c8078940>,
#  'mercato_bn:00053458n': <gensim.models.keyedvectors.Vocab at 0x1e1c8078978>,
#  'reagire_bn:00092421v': <gensim.models.keyedvectors.Vocab at 0x1e1c80789b0>,
#  'sempre': <gensim.models.keyedvectors.Vocab at 0x1e1c80789e8>,
#  'razionale_bn:00109453a': <gensim.models.keyedvectors.Vocab at 0x1e1c8078a20>,
#  'rivelare_bn:00092109v': <gensim.models.keyedvectors.Vocab at 0x1e1c8078a58>,
#  'sistemi': <gensim.models.keyedvectors.Vocab at 0x1e1c8078a90>,
#  'economico_bn:00099557a': <gensim.models.keyedvectors.Vocab at 0x1e1c8078ac8>,
#  'diventati': <gensim.models.keyedvectors.Vocab at 0x1e1c8078b00>,
#  'interdipendente_bn:00105272a': <gensim.models.keyedvectors.Vocab at 0x1e1c8078b38>,
#  'eppure_bn:00114216r': <gensim.models.keyedvectors.Vocab at 0x1e1c8078b70>,
#  'nonostante': <gensim.models.keyedvectors.Vocab at 0x1e1c8078ba8>,
#  'generalizzare_bn:00087930v': <gensim.models.keyedvectors.Vocab at 0x1e1c8078be0>,
#  'crisi_bn:00026403n': <gensim.models.keyedvectors.Vocab at 0x1e1c8078c18>,
#  'pessimismo': <gensim.models.keyedvectors.Vocab at 0x1e1c8078c50>,
#  'mitigare_bn:00082530v': <gensim.models.keyedvectors.Vocab at 0x1e1c8078c88>,
#  'fatto_bn:00042904n': <gensim.models.keyedvectors.Vocab at 0x1e1c8078cc0>,
#  'riuscire_bn:00083181v': <gensim.models.keyedvectors.Vocab at 0x1e1c8078cf8>,
#  'mantenere_bn:00089384v': <gensim.models.keyedvectors.Vocab at 0x1e1c8078d30>,
#  'forte_bn:00100315a': <gensim.models.keyedvectors.Vocab at 0x1e1c8078d68>,
#  'stabilit\\xc3\\xa0_bn:00031312n': <gensim.models.keyedvectors.Vocab at 0x1e1c8078da0>,
#  'intorno': <gensim.models.keyedvectors.Vocab at 0x1e1c8078dd8>,
#  'qualche': <gensim.models.keyedvectors.Vocab at 0x1e1c8078e10>,
#  'anno_bn:00081857n': <gensim.models.keyedvectors.Vocab at 0x1e1c8078e48>,
#  'fa': <gensim.models.keyedvectors.Vocab at 0x1e1c8078e80>,
#  'ritenere_bn:00086433v': <gensim.models.keyedvectors.Vocab at 0x1e1c8078eb8>,
#  'possibile_bn:00108829a': <gensim.models.keyedvectors.Vocab at 0x1e1c8078ef0>,
#  'moneta_bn:00055644n': <gensim.models.keyedvectors.Vocab at 0x1e1c8078f28>,
#  'debole_bn:00102875a': <gensim.models.keyedvectors.Vocab at 0x1e1c8078f60>,
#  'sistema': <gensim.models.keyedvectors.Vocab at 0x1e1c8078f98>,
#  'monetario_bn:00106867a': <gensim.models.keyedvectors.Vocab at 0x1e1c8078fd0>,
#  'stare_bn:00083181v': <gensim.models.keyedvectors.Vocab at 0x1e1c807b048>,
#  'grado_bn:00025965n': <gensim.models.keyedvectors.Vocab at 0x1e1c807b080>,
#  'resistere_bn:00087620v': <gensim.models.keyedvectors.Vocab at 0x1e1c807b0b8>,
#  'speculazione_bn:00073240n': <gensim.models.keyedvectors.Vocab at 0x1e1c807b0f0>,
#  'oscillazione_bn:00075592n': <gensim.models.keyedvectors.Vocab at 0x1e1c807b128>,
#  'corso_bn:00023287n': <gensim.models.keyedvectors.Vocab at 0x1e1c807b160>,
#  'cambio_bn:00032134n': <gensim.models.keyedvectors.Vocab at 0x1e1c807b198>,
#  'dollaro_bn:00079129n': <gensim.models.keyedvectors.Vocab at 0x1e1c807b1d0>,
#  'sovranit\\xc3\\xa0_bn:00066963n': <gensim.models.keyedvectors.Vocab at 0x1e1c807b208>,
#  'perdere_bn:00090491v': <gensim.models.keyedvectors.Vocab at 0x1e1c807b240>,
#  'quando': <gensim.models.keyedvectors.Vocab at 0x1e1c807b278>,
#  'ciascuno': <gensim.models.keyedvectors.Vocab at 0x1e1c807b2b0>,
#  'conto_bn:00000740n': <gensim.models.keyedvectors.Vocab at 0x1e1c807b2e8>,
#  'dispetto_bn:00010743n': <gensim.models.keyedvectors.Vocab at 0x1e1c807b320>,
#  'scetticismo_bn:00002059n': <gensim.models.keyedvectors.Vocab at 0x1e1c807b358>,
#  'uni': <gensim.models.keyedvectors.Vocab at 0x1e1c807b390>,
#  'ostilit\\xc3\\xa0_bn:00004467n': <gensim.models.keyedvectors.Vocab at 0x1e1c807b3c8>,
#  'altri': <gensim.models.keyedvectors.Vocab at 0x1e1c807b400>,
#  'indifferenza_bn:00030586n': <gensim.models.keyedvectors.Vocab at 0x1e1c807b438>,
#  'potere_bn:00084450v': <gensim.models.keyedvectors.Vocab at 0x1e1c807b470>,
#  'soddisfare_bn:00082225v': <gensim.models.keyedvectors.Vocab at 0x1e1c807b4a8>,
#  'aver': <gensim.models.keyedvectors.Vocab at 0x1e1c807b4e0>,
#  'incentrato': <gensim.models.keyedvectors.Vocab at 0x1e1c807b518>,
#  'sforzo_bn:00074633n': <gensim.models.keyedvectors.Vocab at 0x1e1c807b550>,
#  'creazione_bn:00022991n': <gensim.models.keyedvectors.Vocab at 0x1e1c807b588>,
#  'unione_bn:00079077n': <gensim.models.keyedvectors.Vocab at 0x1e1c807b5c0>,
#  'adesso_bn:00116381r': <gensim.models.keyedvectors.Vocab at 0x1e1c807b5f8>,
#  'grazie': <gensim.models.keyedvectors.Vocab at 0x1e1c807b630>,
#  'quest&apos;': <gensim.models.keyedvectors.Vocab at 0x1e1c807b668>,
#  'ultima': <gensim.models.keyedvectors.Vocab at 0x1e1c807b6a0>,
#  'grado_bn:00025966n': <gensim.models.keyedvectors.Vocab at 0x1e1c807b6d8>,
#  'assumere_bn:00082202v': <gensim.models.keyedvectors.Vocab at 0x1e1c807b710>,
#  'nuovo_bn:00103327a': <gensim.models.keyedvectors.Vocab at 0x1e1c807b748>,
#  'impegno_bn:00029239n': <gensim.models.keyedvectors.Vocab at 0x1e1c807b780>,
#  'undici': <gensim.models.keyedvectors.Vocab at 0x1e1c807b7b8>,
#  'aderire_bn:00088013v': <gensim.models.keyedvectors.Vocab at 0x1e1c807b7f0>,
#  'dare_bn:00088815v': <gensim.models.keyedvectors.Vocab at 0x1e1c807b828>,
#  'comune_bn:00100091a': <gensim.models.keyedvectors.Vocab at 0x1e1c807b860>,
#  'status_bn:00063703n': <gensim.models.keyedvectors.Vocab at 0x1e1c807b898>,
#  'specifico_bn:00099532a': <gensim.models.keyedvectors.Vocab at 0x1e1c807b8d0>,
#  'rapporto_bn:00035732n': <gensim.models.keyedvectors.Vocab at 0x1e1c807b908>,
#  'esterno_bn:00102624a': <gensim.models.keyedvectors.Vocab at 0x1e1c807b940>,
#  'fuori': <gensim.models.keyedvectors.Vocab at 0x1e1c807b978>,
#  'confine_bn:00012212n': <gensim.models.keyedvectors.Vocab at 0x1e1c807b9b0>,
#  'pensare_bn:00094907v': <gensim.models.keyedvectors.Vocab at 0x1e1c807b9e8>,
#  'particolare_bn:00026622n': <gensim.models.keyedvectors.Vocab at 0x1e1c807ba20>,
#  'g7': <gensim.models.keyedvectors.Vocab at 0x1e1c807ba58>,
#  'effettivamente_bn:00115504r': <gensim.models.keyedvectors.Vocab at 0x1e1c807ba90>,
#  'sentire_bn:00088098v': <gensim.models.keyedvectors.Vocab at 0x1e1c807bac8>,
#  'peso': <gensim.models.keyedvectors.Vocab at 0x1e1c807bb00>,
#  'commercio_bn:00077860n': <gensim.models.keyedvectors.Vocab at 0x1e1c807bb38>,
#  'trasformare_bn:00084787v': <gensim.models.keyedvectors.Vocab at 0x1e1c807bb70>,
#  'gigante': <gensim.models.keyedvectors.Vocab at 0x1e1c807bba8>,
#  'punto_bn:00062699n': <gensim.models.keyedvectors.Vocab at 0x1e1c807bbe0>,
#  'vista_bn:00045979n': <gensim.models.keyedvectors.Vocab at 0x1e1c807bc18>,
#  'economico_bn:00102003a': <gensim.models.keyedvectors.Vocab at 0x1e1c807bc50>,
#  'sociale_bn:00110842a': <gensim.models.keyedvectors.Vocab at 0x1e1c807bc88>,
#  'rimanere_bn:00083181v': <gensim.models.keyedvectors.Vocab at 0x1e1c807bcc0>,
#  'nano_bn:00029248n': <gensim.models.keyedvectors.Vocab at 0x1e1c807bcf8>,
#  'ambito_bn:00007985n': <gensim.models.keyedvectors.Vocab at 0x1e1c807bd30>,
#  'diplomatico_bn:00101405a': <gensim.models.keyedvectors.Vocab at 0x1e1c807bd68>,
#  'strategico_bn:00111285a': <gensim.models.keyedvectors.Vocab at 0x1e1c807bda0>,
#  'chiedere_bn:00092265v': <gensim.models.keyedvectors.Vocab at 0x1e1c807bdd8>,
#  'momento_bn:00077321n': <gensim.models.keyedvectors.Vocab at 0x1e1c807be10>,
#  'situazione_bn:00063707n': <gensim.models.keyedvectors.Vocab at 0x1e1c807be48>,
#  'balcani': <gensim.models.keyedvectors.Vocab at 0x1e1c807be80>,
#  'esplosivo_bn:00102595a': <gensim.models.keyedvectors.Vocab at 0x1e1c807beb8>,
#  'mai': <gensim.models.keyedvectors.Vocab at 0x1e1c807bef0>,
#  'attuazione_bn:00016287n': <gensim.models.keyedvectors.Vocab at 0x1e1c807bf28>,
#  'anticipare_bn:00082666v': <gensim.models.keyedvectors.Vocab at 0x1e1c807bf60>,
#  'disposizione_bn:00005864n': <gensim.models.keyedvectors.Vocab at 0x1e1c807bf98>,
#  'ritenere_bn:00089388v': <gensim.models.keyedvectors.Vocab at 0x1e1c807bfd0>,
#  'concittadino_bn:00077784n': <gensim.models.keyedvectors.Vocab at 0x1e1c807f048>,
#  'attribuire_bn:00082815v': <gensim.models.keyedvectors.Vocab at 0x1e1c807f080>,
#  'grande_bn:00101605a': <gensim.models.keyedvectors.Vocab at 0x1e1c807f0b8>,
#  'importanza_bn:00046143n': <gensim.models.keyedvectors.Vocab at 0x1e1c807f0f0>,
#  'due': <gensim.models.keyedvectors.Vocab at 0x1e1c807f128>,
#  'libert\\xc3\\xa0_bn:00050954n': <gensim.models.keyedvectors.Vocab at 0x1e1c807f160>,
#  'fondamentale_bn:00099258a': <gensim.models.keyedvectors.Vocab at 0x1e1c807f198>,
#  'sicurezza': <gensim.models.keyedvectors.Vocab at 0x1e1c807f1d0>,
#  'libero_bn:00103299a': <gensim.models.keyedvectors.Vocab at 0x1e1c807f208>,
#  'circolazione_bn:00019200n': <gensim.models.keyedvectors.Vocab at 0x1e1c807f240>,
#  'lavoratore_bn:00047795n': <gensim.models.keyedvectors.Vocab at 0x1e1c807f278>,
#  'timore_bn:00033854n': <gensim.models.keyedvectors.Vocab at 0x1e1c807f2b0>,
#  'subire_bn:00088740v': <gensim.models.keyedvectors.Vocab at 0x1e1c807f2e8>,
#  'crimine_bn:00023807n': <gensim.models.keyedvectors.Vocab at 0x1e1c807f320>,
#  'vivere_bn:00087862v': <gensim.models.keyedvectors.Vocab at 0x1e1c807f358>,
#  'insicurezza_bn:00046877n': <gensim.models.keyedvectors.Vocab at 0x1e1c807f390>,
#  'priorit\\xc3\\xa0': <gensim.models.keyedvectors.Vocab at 0x1e1c807f3c8>,
#  'vertice_bn:00075159n': <gensim.models.keyedvectors.Vocab at 0x1e1c807f400>,
#  'p\\xc3\\xb6rtschach': <gensim.models.keyedvectors.Vocab at 0x1e1c807f438>,
#  'evidente_bn:00097350a': <gensim.models.keyedvectors.Vocab at 0x1e1c807f470>,
#  'conto_bn:00014688n': <gensim.models.keyedvectors.Vocab at 0x1e1c807f4a8>,
#  'fatto_bn:00001127n': <gensim.models.keyedvectors.Vocab at 0x1e1c807f4e0>,
#  'futuro_bn:00103449a': <gensim.models.keyedvectors.Vocab at 0x1e1c807f518>,
#  'comporre_bn:00085488v': <gensim.models.keyedvectors.Vocab at 0x1e1c807f550>,
#  '27': <gensim.models.keyedvectors.Vocab at 0x1e1c807f588>,
#  'membro_bn:00054278n': <gensim.models.keyedvectors.Vocab at 0x1e1c807f5c0>,
#  'portare_bn:00084060v': <gensim.models.keyedvectors.Vocab at 0x1e1c807f5f8>,
#  's\\xc3\\xa9_bn:00029935n': <gensim.models.keyedvectors.Vocab at 0x1e1c807f630>,
#  'germe_bn:00054731n': <gensim.models.keyedvectors.Vocab at 0x1e1c807f668>,
#  'inaridimento': <gensim.models.keyedvectors.Vocab at 0x1e1c807f6a0>,
#  'conquista_bn:00007006n': <gensim.models.keyedvectors.Vocab at 0x1e1c807f6d8>,
#  'ottenere_bn:00082226v': <gensim.models.keyedvectors.Vocab at 0x1e1c807f710>,
#  'cinquant&apos;': <gensim.models.keyedvectors.Vocab at 0x1e1c807f748>,
#  'lavoro_bn:00030616n': <gensim.models.keyedvectors.Vocab at 0x1e1c807f780>,
#  'forte_bn:00111312a': <gensim.models.keyedvectors.Vocab at 0x1e1c807f7b8>,
#  'europeo': <gensim.models.keyedvectors.Vocab at 0x1e1c807f7f0>,
#  'ricordare_bn:00082272v': <gensim.models.keyedvectors.Vocab at 0x1e1c807f828>,
#  'onorevole_bn:00054280n': <gensim.models.keyedvectors.Vocab at 0x1e1c807f860>,
#  'de': <gensim.models.keyedvectors.Vocab at 0x1e1c807f898>,
#  'giovanni': <gensim.models.keyedvectors.Vocab at 0x1e1c807f8d0>,
#  'ribadire_bn:00092439v': <gensim.models.keyedvectors.Vocab at 0x1e1c807f908>,
#  'necessit\\xc3\\xa0_bn:00056037n': <gensim.models.keyedvectors.Vocab at 0x1e1c807f940>,
#  'coinvolgere_bn:00082428v': <gensim.models.keyedvectors.Vocab at 0x1e1c807f978>,
#  'processo_bn:00050563n': <gensim.models.keyedvectors.Vocab at 0x1e1c807f9b0>,
#  'riforma_bn:00064868n': <gensim.models.keyedvectors.Vocab at 0x1e1c807f9e8>,
#  'tre': <gensim.models.keyedvectors.Vocab at 0x1e1c807fa20>,
#  'nazionale_bn:00107136a': <gensim.models.keyedvectors.Vocab at 0x1e1c807fa58>,
#  'viepi\\xc3\\xb9': <gensim.models.keyedvectors.Vocab at 0x1e1c807fa90>,
#  'convincere_bn:00091565v': <gensim.models.keyedvectors.Vocab at 0x1e1c807fac8>,
#  'consiglio_bn:00023134n': <gensim.models.keyedvectors.Vocab at 0x1e1c807fb00>,
#  'salvare_bn:00086533v': <gensim.models.keyedvectors.Vocab at 0x1e1c807fb38>,
#  'pericolo_bn:00030747n': <gensim.models.keyedvectors.Vocab at 0x1e1c807fb70>,
#  'paralisi_bn:00060326n': <gensim.models.keyedvectors.Vocab at 0x1e1c807fba8>,
#  'soltanto_bn:00114234r': <gensim.models.keyedvectors.Vocab at 0x1e1c807fbe0>,
#  'attraverso': <gensim.models.keyedvectors.Vocab at 0x1e1c807fc18>,
#  'maggioranza_bn:00000445n': <gensim.models.keyedvectors.Vocab at 0x1e1c807fc50>,
#  'riguardare_bn:00083240v': <gensim.models.keyedvectors.Vocab at 0x1e1c807fc88>,
#  'aspettare_bn:00082820v': <gensim.models.keyedvectors.Vocab at 0x1e1c807fcc0>,
#  'attribuire_bn:00082857v': <gensim.models.keyedvectors.Vocab at 0x1e1c807fcf8>,
#  'competenza_bn:00048653n': <gensim.models.keyedvectors.Vocab at 0x1e1c807fd30>,
#  'legislativo_bn:00105859a': <gensim.models.keyedvectors.Vocab at 0x1e1c807fd68>,
#  'nonch\\xc3\\xa9': <gensim.models.keyedvectors.Vocab at 0x1e1c807fda0>,
#  'responsabilit\\xc3\\xa0_bn:00029239n': <gensim.models.keyedvectors.Vocab at 0x1e1c807fdd8>,
#  'investitura_bn:00034191n': <gensim.models.keyedvectors.Vocab at 0x1e1c807fe10>,
#  'considerare_bn:00083370v': <gensim.models.keyedvectors.Vocab at 0x1e1c807fe48>,
#  'legittimo_bn:00105788a': <gensim.models.keyedvectors.Vocab at 0x1e1c807fe80>,
#  'approvare_bn:00090286v': <gensim.models.keyedvectors.Vocab at 0x1e1c807feb8>,
#  'inizio_bn:00073989n': <gensim.models.keyedvectors.Vocab at 0x1e1c807fef0>,
#  'trattativa_bn:00026838n': <gensim.models.keyedvectors.Vocab at 0x1e1c807ff28>,
#  'statuto_bn:00050588n': <gensim.models.keyedvectors.Vocab at 0x1e1c807ff60>,
#  'membro_bn:00034004n': <gensim.models.keyedvectors.Vocab at 0x1e1c807ff98>,
#  'desiderare_bn:00086682v': <gensim.models.keyedvectors.Vocab at 0x1e1c807ffd0>,
#  'concludere_bn:00087608v': <gensim.models.keyedvectors.Vocab at 0x1e1c8083048>,
#  'intervento_bn:00007013n': <gensim.models.keyedvectors.Vocab at 0x1e1c8083080>,
#  'nota_bn:00004349n': <gensim.models.keyedvectors.Vocab at 0x1e1c80830b8>,
#  'ottimismo_bn:00059224n': <gensim.models.keyedvectors.Vocab at 0x1e1c80830f0>,
#  'discussione_bn:00027523n': <gensim.models.keyedvectors.Vocab at 0x1e1c8083128>,
#  'positivo_bn:00108822a': <gensim.models.keyedvectors.Vocab at 0x1e1c8083160>,
#  'ieri_bn:00117652r': <gensim.models.keyedvectors.Vocab at 0x1e1c8083198>,
#  'assistere_bn:00091106v': <gensim.models.keyedvectors.Vocab at 0x1e1c80831d0>,
#  'aula_bn:00023302n': <gensim.models.keyedvectors.Vocab at 0x1e1c8083208>,
#  'commovente_bn:00102162a': <gensim.models.keyedvectors.Vocab at 0x1e1c8083240>,
#  'messaggio_bn:00022154n': <gensim.models.keyedvectors.Vocab at 0x1e1c8083278>,
#  'john': <gensim.models.keyedvectors.Vocab at 0x1e1c80832b0>,
#  'hume': <gensim.models.keyedvectors.Vocab at 0x1e1c80832e8>,
#  'sottolineare_bn:00087572v': <gensim.models.keyedvectors.Vocab at 0x1e1c8083320>,
#  'significato_bn:00046139n': <gensim.models.keyedvectors.Vocab at 0x1e1c8083358>,
#  'storico_bn:00104223a': <gensim.models.keyedvectors.Vocab at 0x1e1c8083390>,
#  'riconciliazione': <gensim.models.keyedvectors.Vocab at 0x1e1c80833c8>,
#  'volere_bn:00085647v': <gensim.models.keyedvectors.Vocab at 0x1e1c8083400>,
#  'esprimere_bn:00087778v': <gensim.models.keyedvectors.Vocab at 0x1e1c8083438>,
#  'tutta': <gensim.models.keyedvectors.Vocab at 0x1e1c8083470>,
#  'considerazione_bn:00031653n': <gensim.models.keyedvectors.Vocab at 0x1e1c80834a8>,
#  'nutrire_bn:00088084v': <gensim.models.keyedvectors.Vocab at 0x1e1c80834e0>,
#  'confronto_bn:00063715n': <gensim.models.keyedvectors.Vocab at 0x1e1c8083518>,
#  'accogliere_bn:00095705v': <gensim.models.keyedvectors.Vocab at 0x1e1c8083550>,
#  'onorevole_bn:00113948a': <gensim.models.keyedvectors.Vocab at 0x1e1c8083588>,
#  'collega_bn:00020621n': <gensim.models.keyedvectors.Vocab at 0x1e1c80835c0>,
#  'positivo_bn:00096605a': <gensim.models.keyedvectors.Vocab at 0x1e1c80835f8>,
#  'fare_bn:00086008v': <gensim.models.keyedvectors.Vocab at 0x1e1c8083630>,
#  'riflettere_bn:00084733v': <gensim.models.keyedvectors.Vocab at 0x1e1c8083668>,
#  'futuro_bn:00036941n': <gensim.models.keyedvectors.Vocab at 0x1e1c80836a0>,
#  'vicinanza': <gensim.models.keyedvectors.Vocab at 0x1e1c80836d8>,
#  'cittadino_bn:00019285n': <gensim.models.keyedvectors.Vocab at 0x1e1c8083710>,
#  'insoddisfazione_bn:00027705n': <gensim.models.keyedvectors.Vocab at 0x1e1c8083748>,
#  'tanto_bn:00106408a': <gensim.models.keyedvectors.Vocab at 0x1e1c8083780>,
#  'sufficiente_bn:00111418a': <gensim.models.keyedvectors.Vocab at 0x1e1c80837b8>,
#  'tenere_bn:00090036v': <gensim.models.keyedvectors.Vocab at 0x1e1c80837f0>,
#  'conferenza_bn:00050488n': <gensim.models.keyedvectors.Vocab at 0x1e1c8083828>,
#  'scambiare_bn:00084772v': <gensim.models.keyedvectors.Vocab at 0x1e1c8083860>,
#  'bello_bn:00100315a': <gensim.models.keyedvectors.Vocab at 0x1e1c8083898>,
#  'adatto_bn:00107924a': <gensim.models.keyedvectors.Vocab at 0x1e1c80838d0>,
#  'televisione_bn:00076373n': <gensim.models.keyedvectors.Vocab at 0x1e1c8083908>,
#  'produrre_bn:00084069v': <gensim.models.keyedvectors.Vocab at 0x1e1c8083940>,
#  'alcun': <gensim.models.keyedvectors.Vocab at 0x1e1c8083978>,
#  'risultato_bn:00030721n': <gensim.models.keyedvectors.Vocab at 0x1e1c80839b0>,
#  'pertanto_bn:00115635r': <gensim.models.keyedvectors.Vocab at 0x1e1c80839e8>,
#  'rispetto_bn:00031654n': <gensim.models.keyedvectors.Vocab at 0x1e1c8083a20>,
#  'desiderare_bn:00095802v': <gensim.models.keyedvectors.Vocab at 0x1e1c8083a58>,
#  'chiarezza_bn:00019459n': <gensim.models.keyedvectors.Vocab at 0x1e1c8083a90>,
#  'punto_bn:00063217n': <gensim.models.keyedvectors.Vocab at 0x1e1c8083ac8>,
#  'obiettivo_bn:00030721n': <gensim.models.keyedvectors.Vocab at 0x1e1c8083b00>,
#  'calendario_bn:00014705n': <gensim.models.keyedvectors.Vocab at 0x1e1c8083b38>,
#  'concreto_bn:00100206a': <gensim.models.keyedvectors.Vocab at 0x1e1c8083b70>,
#  'gi\\xc3\\xa0_bn:00114245r': <gensim.models.keyedvectors.Vocab at 0x1e1c8083ba8>,
#  'ci\\xc3\\xb2': <gensim.models.keyedvectors.Vocab at 0x1e1c8083be0>,
#  'manca_bn:00050523n': <gensim.models.keyedvectors.Vocab at 0x1e1c8083c18>,
#  'coraggio_bn:00012839n': <gensim.models.keyedvectors.Vocab at 0x1e1c8083c50>,
#  'governo_bn:00001426n': <gensim.models.keyedvectors.Vocab at 0x1e1c8083c88>,
#  'centralismo': <gensim.models.keyedvectors.Vocab at 0x1e1c8083cc0>,
#  'bruxelles': <gensim.models.keyedvectors.Vocab at 0x1e1c8083cf8>,
#  'pi\\xc3\\xb9_bn:00116291r': <gensim.models.keyedvectors.Vocab at 0x1e1c8083d30>,
#  'volte': <gensim.models.keyedvectors.Vocab at 0x1e1c8083d68>,
#  'lamentato': <gensim.models.keyedvectors.Vocab at 0x1e1c8083da0>,
#  'indecisione_bn:00046384n': <gensim.models.keyedvectors.Vocab at 0x1e1c8083dd8>,
#  'incapacit\\xc3\\xa0_bn:00046261n': <gensim.models.keyedvectors.Vocab at 0x1e1c8083e10>,
#  'risolvere_bn:00088162v': <gensim.models.keyedvectors.Vocab at 0x1e1c8083e48>,
#  'auspico': <gensim.models.keyedvectors.Vocab at 0x1e1c8083e80>,
#  'chiaro_bn:00099802a': <gensim.models.keyedvectors.Vocab at 0x1e1c8083eb8>,
#  'segnale_bn:00071538n': <gensim.models.keyedvectors.Vocab at 0x1e1c8083ef0>,
#  'politico_bn:00108759a': <gensim.models.keyedvectors.Vocab at 0x1e1c8083f28>,
#  'problema_bn:00064526n': <gensim.models.keyedvectors.Vocab at 0x1e1c8083f60>,
#  'principale_bn:00106332a': <gensim.models.keyedvectors.Vocab at 0x1e1c8083f98>,
#  's\\xc3\\xac': <gensim.models.keyedvectors.Vocab at 0x1e1c8083fd0>,
#  'esplicito_bn:00102589a': <gensim.models.keyedvectors.Vocab at 0x1e1c8086048>,
#  'ampliamento_bn:00030922n': <gensim.models.keyedvectors.Vocab at 0x1e1c8086080>,
#  'condizione_bn:00021649n': <gensim.models.keyedvectors.Vocab at 0x1e1c80860b8>,
#  'stabilire_bn:00085671v': <gensim.models.keyedvectors.Vocab at 0x1e1c80860f0>,
#  'fase_bn:00061898n': <gensim.models.keyedvectors.Vocab at 0x1e1c8086128>,
#  'grado_bn:00066154n': <gensim.models.keyedvectors.Vocab at 0x1e1c8086160>,
#  'tali': <gensim.models.keyedvectors.Vocab at 0x1e1c8086198>,
#  'criterio_bn:00023853n': <gensim.models.keyedvectors.Vocab at 0x1e1c80861d0>,
#  'costo_bn:00022995n': <gensim.models.keyedvectors.Vocab at 0x1e1c8086208>,
#  'termine_bn:00081546n': <gensim.models.keyedvectors.Vocab at 0x1e1c8086240>,
#  'finanziario_bn:00098985a': <gensim.models.keyedvectors.Vocab at 0x1e1c8086278>,
#  'pronunciamento': <gensim.models.keyedvectors.Vocab at 0x1e1c80862b0>,
#  'favore_bn:00049132n': <gensim.models.keyedvectors.Vocab at 0x1e1c80862e8>,
#  'miglioramento_bn:00046192n': <gensim.models.keyedvectors.Vocab at 0x1e1c8086320>,
#  'strutture': <gensim.models.keyedvectors.Vocab at 0x1e1c8086358>,
#  'decisionali': <gensim.models.keyedvectors.Vocab at 0x1e1c8086390>,
#  'condizione_bn:00021644n': <gensim.models.keyedvectors.Vocab at 0x1e1c80863c8>,
#  'agire_bn:00082285v': <gensim.models.keyedvectors.Vocab at 0x1e1c8086400>,
#  'riserva_bn:00054992n': <gensim.models.keyedvectors.Vocab at 0x1e1c8086438>,
#  'politica_bn:00063351n': <gensim.models.keyedvectors.Vocab at 0x1e1c8086470>,
#  'estero_bn:00103205a': <gensim.models.keyedvectors.Vocab at 0x1e1c80864a8>,
#  'sicurezza_bn:00068799n': <gensim.models.keyedvectors.Vocab at 0x1e1c80864e0>,
#  'meritare_bn:00086670v': <gensim.models.keyedvectors.Vocab at 0x1e1c8086518>,
#  'davvero_bn:00115504r': <gensim.models.keyedvectors.Vocab at 0x1e1c8086550>,
#  'interesse_bn:00047080n': <gensim.models.keyedvectors.Vocab at 0x1e1c8086588>,
#  'pace_bn:00061149n': <gensim.models.keyedvectors.Vocab at 0x1e1c80865c0>,
#  'continente_bn:00022173n': <gensim.models.keyedvectors.Vocab at 0x1e1c80865f8>,
#  'mondo_bn:00029424n': <gensim.models.keyedvectors.Vocab at 0x1e1c8086630>,
#  'centro_bn:00014155n': <gensim.models.keyedvectors.Vocab at 0x1e1c8086668>,
#  'potere_bn:00063940n': <gensim.models.keyedvectors.Vocab at 0x1e1c80866a0>,
#  'costituire_bn:00088488v': <gensim.models.keyedvectors.Vocab at 0x1e1c80866d8>,
#  'capo_bn:00012293n': <gensim.models.keyedvectors.Vocab at 0x1e1c8086710>,
#  'decidere_bn:00086370v': <gensim.models.keyedvectors.Vocab at 0x1e1c8086748>,
#  'attuale_bn:00100790a': <gensim.models.keyedvectors.Vocab at 0x1e1c8086780>,
#  'appello': <gensim.models.keyedvectors.Vocab at 0x1e1c80867b8>,
#  'semestre_bn:00070408n': <gensim.models.keyedvectors.Vocab at 0x1e1c80867f0>,
#  'presidenza_bn:00017517n': <gensim.models.keyedvectors.Vocab at 0x1e1c8086828>,
#  'sapere_bn:00086933v': <gensim.models.keyedvectors.Vocab at 0x1e1c8086860>,
#  'ovviare': <gensim.models.keyedvectors.Vocab at 0x1e1c8086898>,
#  'carenza_bn:00025913n': <gensim.models.keyedvectors.Vocab at 0x1e1c80868d0>,
#  'fondamentale_bn:00103424a': <gensim.models.keyedvectors.Vocab at 0x1e1c8086908>,
#  'deputato_bn:00026427n': <gensim.models.keyedvectors.Vocab at 0x1e1c8086940>,
#  'contribuire_bn:00085565v': <gensim.models.keyedvectors.Vocab at 0x1e1c8086978>,
#  'piacere_bn:00086519v': <gensim.models.keyedvectors.Vocab at 0x1e1c80869b0>,
#  'portare_bn:00090245v': <gensim.models.keyedvectors.Vocab at 0x1e1c80869e8>,
#  'avanti_bn:00115431r': <gensim.models.keyedvectors.Vocab at 0x1e1c8086a20>,
#  'integrazione': <gensim.models.keyedvectors.Vocab at 0x1e1c8086a58>,
#  'compito_bn:00049573n': <gensim.models.keyedvectors.Vocab at 0x1e1c8086a90>,
#  'spetta': <gensim.models.keyedvectors.Vocab at 0x1e1c8086ac8>,
#  'innanzitutto_bn:00114082r': <gensim.models.keyedvectors.Vocab at 0x1e1c8086b00>,
#  'apprezzare_bn:00082722v': <gensim.models.keyedvectors.Vocab at 0x1e1c8086b38>,
#  'volont\\xc3\\xa0': <gensim.models.keyedvectors.Vocab at 0x1e1c8086b70>,
#  'carica_bn:00010073n': <gensim.models.keyedvectors.Vocab at 0x1e1c8086ba8>,
#  'strada_bn:00067975n': <gensim.models.keyedvectors.Vocab at 0x1e1c8086be0>,
#  'autentico_bn:00101997a': <gensim.models.keyedvectors.Vocab at 0x1e1c8086c18>,
#  'servizio_bn:00070651n': <gensim.models.keyedvectors.Vocab at 0x1e1c8086c50>,
#  'sviluppo_bn:00026694n': <gensim.models.keyedvectors.Vocab at 0x1e1c8086c88>,
#  'modello_bn:00036197n': <gensim.models.keyedvectors.Vocab at 0x1e1c8086cc0>,
#  'sociale_bn:00110843a': <gensim.models.keyedvectors.Vocab at 0x1e1c8086cf8>,
#  'sottolineare_bn:00082195v': <gensim.models.keyedvectors.Vocab at 0x1e1c8086d30>,
#  'per\\xc3\\xb2': <gensim.models.keyedvectors.Vocab at 0x1e1c8086d68>,
#  'divario_bn:00037277n': <gensim.models.keyedvectors.Vocab at 0x1e1c8086da0>,
#  'intenzione_bn:00002178n': <gensim.models.keyedvectors.Vocab at 0x1e1c8086dd8>,
#  'comportamento_bn:00009657n': <gensim.models.keyedvectors.Vocab at 0x1e1c8086e10>,
#  'fronte_bn:00013389n': <gensim.models.keyedvectors.Vocab at 0x1e1c8086e48>,
#  'ritenere_bn:00086435v': <gensim.models.keyedvectors.Vocab at 0x1e1c8086e80>,
#  'indispensabile_bn:00107182a': <gensim.models.keyedvectors.Vocab at 0x1e1c8086eb8>,
#  'particolare_bn:00113366a': <gensim.models.keyedvectors.Vocab at 0x1e1c8086ef0>,
#  'assumere_bn:00088178v': <gensim.models.keyedvectors.Vocab at 0x1e1c8086f28>,
#  'proprie': <gensim.models.keyedvectors.Vocab at 0x1e1c8086f60>,
#  'sensibile_bn:00110409a': <gensim.models.keyedvectors.Vocab at 0x1e1c8086f98>,
#  'rallentamento_bn:00025683n': <gensim.models.keyedvectors.Vocab at 0x1e1c8086fd0>,
# ...
#  'teatro_bn:00028609n': <gensim.models.keyedvectors.Vocab at 0x1e1c80912e8>,
#  'scontro_bn:00027421n': <gensim.models.keyedvectors.Vocab at 0x1e1c8091320>,
#  'interesse_bn:00047077n': <gensim.models.keyedvectors.Vocab at 0x1e1c8091358>,
#  'matrice_bn:00053849n': <gensim.models.keyedvectors.Vocab at 0x1e1c8091390>,
#  'nazionalistica': <gensim.models.keyedvectors.Vocab at 0x1e1c80913c8>,
#  'vertice_bn:00079833n': <gensim.models.keyedvectors.Vocab at 0x1e1c8091400>,
#  'dimostrare_bn:00086567v': <gensim.models.keyedvectors.Vocab at 0x1e1c8091438>,
#  'aprire_bn:00091165v': <gensim.models.keyedvectors.Vocab at 0x1e1c8091470>,
#  'po': <gensim.models.keyedvectors.Vocab at 0x1e1c80914a8>,
#  'pi\\xc3\\xb9_bn:00116285r': <gensim.models.keyedvectors.Vocab at 0x1e1c80914e0>,
#  'spiraglio_bn:00040637n': <gensim.models.keyedvectors.Vocab at 0x1e1c8091518>,
#  'relazione_bn:00045161n': <gensim.models.keyedvectors.Vocab at 0x1e1c8091550>,
#  'evidenziare_bn:00087572v': <gensim.models.keyedvectors.Vocab at 0x1e1c8091588>,
#  'autocompiacimento_bn:00021345n': <gensim.models.keyedvectors.Vocab at 0x1e1c80915c0>,
#  'fare_bn:00083184v': <gensim.models.keyedvectors.Vocab at 0x1e1c80915f8>,
#  'euroland': <gensim.models.keyedvectors.Vocab at 0x1e1c8091630>,
#  'francia': <gensim.models.keyedvectors.Vocab at 0x1e1c8091668>,
#  'riparo_bn:00071019n': <gensim.models.keyedvectors.Vocab at 0x1e1c80916a0>,
#  'disordine_bn:00027636n': <gensim.models.keyedvectors.Vocab at 0x1e1c80916d8>,
#  'minaccia_bn:00013843n': <gensim.models.keyedvectors.Vocab at 0x1e1c8091710>,
#  'recessione_bn:00066516n': <gensim.models.keyedvectors.Vocab at 0x1e1c8091748>,
#  'fluttuazione_bn:00035414n': <gensim.models.keyedvectors.Vocab at 0x1e1c8091780>,
#  'realt\\xc3\\xa0_bn:00066414n': <gensim.models.keyedvectors.Vocab at 0x1e1c80917b8>,
#  'rettificare_bn:00082576v': <gensim.models.keyedvectors.Vocab at 0x1e1c80917f0>,
#  'verso': <gensim.models.keyedvectors.Vocab at 0x1e1c8091828>,
#  'basso_bn:00008923n': <gensim.models.keyedvectors.Vocab at 0x1e1c8091860>,
#  'previsione_bn:00035806n': <gensim.models.keyedvectors.Vocab at 0x1e1c8091898>,
#  'crescita_bn:00026697n': <gensim.models.keyedvectors.Vocab at 0x1e1c80918d0>,
#  'economico_bn:00102002a': <gensim.models.keyedvectors.Vocab at 0x1e1c8091908>,
#  'solo': <gensim.models.keyedvectors.Vocab at 0x1e1c8091940>,
#  'germania': <gensim.models.keyedvectors.Vocab at 0x1e1c8091978>,
#  'chiedere_bn:00082817v': <gensim.models.keyedvectors.Vocab at 0x1e1c80919b0>,
#  'criterio_bn:00021164n': <gensim.models.keyedvectors.Vocab at 0x1e1c80919e8>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x1e1c8091a20>,
#  'percento_bn:00061135n': <gensim.models.keyedvectors.Vocab at 0x1e1c8091a58>,
#  'deficit_bn:00013642n': <gensim.models.keyedvectors.Vocab at 0x1e1c8091a90>,
#  '1999': <gensim.models.keyedvectors.Vocab at 0x1e1c8091ac8>,
#  'proposito_bn:00002178n': <gensim.models.keyedvectors.Vocab at 0x1e1c8091b00>,
#  'economico_bn:00102001a': <gensim.models.keyedvectors.Vocab at 0x1e1c8091b38>,
#  'annunciare_bn:00082639v': <gensim.models.keyedvectors.Vocab at 0x1e1c8091b70>,
#  'momento': <gensim.models.keyedvectors.Vocab at 0x1e1c8091ba8>,
#  'uruguay': <gensim.models.keyedvectors.Vocab at 0x1e1c8091be0>,
#  'round': <gensim.models.keyedvectors.Vocab at 0x1e1c8091c18>,
#  'ossia': <gensim.models.keyedvectors.Vocab at 0x1e1c8091c50>,
#  'giro_bn:00040545n': <gensim.models.keyedvectors.Vocab at 0x1e1c8091c88>,
#  'dieci_bn:00095888a': <gensim.models.keyedvectors.Vocab at 0x1e1c8091cc0>,
#  'duecento': <gensim.models.keyedvectors.Vocab at 0x1e1c8091cf8>,
#  'miliardi': <gensim.models.keyedvectors.Vocab at 0x1e1c8091d30>,
#  'ricchezza_bn:00080746n': <gensim.models.keyedvectors.Vocab at 0x1e1c8091d68>,
#  'supplementare_bn:00096432a': <gensim.models.keyedvectors.Vocab at 0x1e1c8091da0>,
#  'sud-est': <gensim.models.keyedvectors.Vocab at 0x1e1c8091dd8>,
#  'asiatico_bn:00097584a': <gensim.models.keyedvectors.Vocab at 0x1e1c8091e10>,
#  'emergenti': <gensim.models.keyedvectors.Vocab at 0x1e1c8091e48>,
#  'cosa': <gensim.models.keyedvectors.Vocab at 0x1e1c8091e80>,
#  'dubbio_bn:00101741a': <gensim.models.keyedvectors.Vocab at 0x1e1c8091eb8>,
#  'tratto_bn:00061605n': <gensim.models.keyedvectors.Vocab at 0x1e1c8091ef0>,
#  'profitto': <gensim.models.keyedvectors.Vocab at 0x1e1c8091f28>,
#  'ricordare_bn:00092763v': <gensim.models.keyedvectors.Vocab at 0x1e1c8091f60>,
#  'assicurazione_bn:00046996n': <gensim.models.keyedvectors.Vocab at 0x1e1c8091f98>,
#  'fornire_bn:00088816v': <gensim.models.keyedvectors.Vocab at 0x1e1c8091fd0>,
#  'jacques': <gensim.models.keyedvectors.Vocab at 0x1e1c8094048>,
#  'delors': <gensim.models.keyedvectors.Vocab at 0x1e1c8094080>,
#  '1994': <gensim.models.keyedvectors.Vocab at 0x1e1c80940b8>,
#  'rispondere_bn:00082646v': <gensim.models.keyedvectors.Vocab at 0x1e1c80940f0>,
#  'domanda_bn:00047208n': <gensim.models.keyedvectors.Vocab at 0x1e1c8094128>,
#  'preparatoria': <gensim.models.keyedvectors.Vocab at 0x1e1c8094160>,
#  'carattere_bn:00017761n': <gensim.models.keyedvectors.Vocab at 0x1e1c8094198>,
#  'recessivo_bn:00109527a': <gensim.models.keyedvectors.Vocab at 0x1e1c80941d0>,
#  'inno_bn:00004527n': <gensim.models.keyedvectors.Vocab at 0x1e1c8094208>,
#  'gioia_bn:00042905n': <gensim.models.keyedvectors.Vocab at 0x1e1c8094240>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x1e1c8094278>,
#  'maggio_bn:00053941n': <gensim.models.keyedvectors.Vocab at 0x1e1c80942b0>,
#  'scorso_bn:00105739a': <gensim.models.keyedvectors.Vocab at 0x1e1c80942e8>,
#  'turbare_bn:00095531v': <gensim.models.keyedvectors.Vocab at 0x1e1c8094320>,
#  'episodio_bn:00042904n': <gensim.models.keyedvectors.Vocab at 0x1e1c8094358>,
#  'trichet': <gensim.models.keyedvectors.Vocab at 0x1e1c8094390>,
#  '15': <gensim.models.keyedvectors.Vocab at 0x1e1c80943c8>,
#  'annunciare_bn:00087811v': <gensim.models.keyedvectors.Vocab at 0x1e1c8094400>,
#  'decennio_bn:00025646n': <gensim.models.keyedvectors.Vocab at 0x1e1c8094438>,
#  'prosperit\\xc3\\xa0_bn:00064819n': <gensim.models.keyedvectors.Vocab at 0x1e1c8094470>,
#  'fortunatamente_bn:00114363r': <gensim.models.keyedvectors.Vocab at 0x1e1c80944a8>,
#  'proteggere_bn:00092103v': <gensim.models.keyedvectors.Vocab at 0x1e1c80944e0>,
#  'grazia_bn:00041221n': <gensim.models.keyedvectors.Vocab at 0x1e1c8094518>,
#  'nulla': <gensim.models.keyedvectors.Vocab at 0x1e1c8094550>,
#  'finalmente_bn:00114417r': <gensim.models.keyedvectors.Vocab at 0x1e1c8094588>,
#  'assolutamente_bn:00114091r': <gensim.models.keyedvectors.Vocab at 0x1e1c80945c0>,
#  'sole_bn:00075170n': <gensim.models.keyedvectors.Vocab at 0x1e1c80945f8>,
#  'ogni': <gensim.models.keyedvectors.Vocab at 0x1e1c8094630>,
#  'pretesto_bn:00002715n': <gensim.models.keyedvectors.Vocab at 0x1e1c8094668>,
#  'giuridico_bn:00105849a': <gensim.models.keyedvectors.Vocab at 0x1e1c80946a0>,
#  'dirigente_bn:00014158n': <gensim.models.keyedvectors.Vocab at 0x1e1c80946d8>,
#  'francese_bn:00103321a': <gensim.models.keyedvectors.Vocab at 0x1e1c8094710>,
#  'offrire_bn:00091137v': <gensim.models.keyedvectors.Vocab at 0x1e1c8094748>,
#  'alcuna': <gensim.models.keyedvectors.Vocab at 0x1e1c8094780>,
#  'contropartita': <gensim.models.keyedvectors.Vocab at 0x1e1c80947b8>,
#  'osare_bn:00086279v': <gensim.models.keyedvectors.Vocab at 0x1e1c80947f0>,
#  'neppure': <gensim.models.keyedvectors.Vocab at 0x1e1c8094828>,
#  'chiedere_bn:00083437v': <gensim.models.keyedvectors.Vocab at 0x1e1c8094860>,
#  'sentire_bn:00082472v': <gensim.models.keyedvectors.Vocab at 0x1e1c8094898>,
#  'presunti': <gensim.models.keyedvectors.Vocab at 0x1e1c80948d0>,
#  'presentare_bn:00091979v': <gensim.models.keyedvectors.Vocab at 0x1e1c8094908>,
#  'rinuncia_bn:00067123n': <gensim.models.keyedvectors.Vocab at 0x1e1c8094940>,
#  'altrettanti': <gensim.models.keyedvectors.Vocab at 0x1e1c8094978>,
#  'successo_bn:00078365n': <gensim.models.keyedvectors.Vocab at 0x1e1c80949b0>,
#  'sembrare_bn:00082693v': <gensim.models.keyedvectors.Vocab at 0x1e1c80949e8>,
#  'improntato': <gensim.models.keyedvectors.Vocab at 0x1e1c8094a20>,
#  'certo_bn:00110911a': <gensim.models.keyedvectors.Vocab at 0x1e1c8094a58>,
#  'stanchezza_bn:00012232n': <gensim.models.keyedvectors.Vocab at 0x1e1c8094a90>,
#  'nessuno': <gensim.models.keyedvectors.Vocab at 0x1e1c8094ac8>,
#  'ignorare_bn:00091032v': <gensim.models.keyedvectors.Vocab at 0x1e1c8094b00>,
#  'carattere_bn:00003057n': <gensim.models.keyedvectors.Vocab at 0x1e1c8094b38>,
#  'artificiale': <gensim.models.keyedvectors.Vocab at 0x1e1c8094b70>,
#  'opinione': <gensim.models.keyedvectors.Vocab at 0x1e1c8094ba8>,
#  'pubblica': <gensim.models.keyedvectors.Vocab at 0x1e1c8094be0>,
#  'lungo': <gensim.models.keyedvectors.Vocab at 0x1e1c8094c18>,
#  'considerare_bn:00087737v': <gensim.models.keyedvectors.Vocab at 0x1e1c8094c50>,
#  'soltanto_bn:00114626r': <gensim.models.keyedvectors.Vocab at 0x1e1c8094c88>,
#  'punti': <gensim.models.keyedvectors.Vocab at 0x1e1c8094cc0>,
#  'pi\\xc3\\xb9_bn:00115418r': <gensim.models.keyedvectors.Vocab at 0x1e1c8094cf8>,
#  'recente_bn:00107267a': <gensim.models.keyedvectors.Vocab at 0x1e1c8094d30>,
#  'frode_bn:00036292n': <gensim.models.keyedvectors.Vocab at 0x1e1c8094d68>,
#  'seduta_bn:00070689n': <gensim.models.keyedvectors.Vocab at 0x1e1c8094da0>,
#  'porta_bn:00028247n': <gensim.models.keyedvectors.Vocab at 0x1e1c8094dd8>,
#  'chiuso_bn:00099877a': <gensim.models.keyedvectors.Vocab at 0x1e1c8094e10>,
#  'incapace_bn:00112254a': <gensim.models.keyedvectors.Vocab at 0x1e1c8094e48>,
#  'globalmente_bn:00115520r': <gensim.models.keyedvectors.Vocab at 0x1e1c8094e80>,
#  'segno_bn:00075652n': <gensim.models.keyedvectors.Vocab at 0x1e1c8094eb8>,
#  '18': <gensim.models.keyedvectors.Vocab at 0x1e1c8094ef0>,
#  'milione_bn:00000013n': <gensim.models.keyedvectors.Vocab at 0x1e1c8094f28>,
#  'disoccupato_bn:00079045n': <gensim.models.keyedvectors.Vocab at 0x1e1c8094f60>,
#  'rispondere_bn:00092421v': <gensim.models.keyedvectors.Vocab at 0x1e1c8094f98>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x1e1c8094fd0>,
#  'practice': <gensim.models.keyedvectors.Vocab at 0x1e1c8098048>,
#  'aspettative': <gensim.models.keyedvectors.Vocab at 0x1e1c8098080>,
#  'approccio_bn:00005142n': <gensim.models.keyedvectors.Vocab at 0x1e1c80980b8>,
#  'lettera_bn:00050802n': <gensim.models.keyedvectors.Vocab at 0x1e1c80980f0>,
#  'accompagnare_bn:00082222v': <gensim.models.keyedvectors.Vocab at 0x1e1c8098128>,
#  'proverranno': <gensim.models.keyedvectors.Vocab at 0x1e1c8098160>,
#  'trattare_bn:00086332v': <gensim.models.keyedvectors.Vocab at 0x1e1c8098198>,
#  'vicinanza_bn:00027749n': <gensim.models.keyedvectors.Vocab at 0x1e1c80981d0>,
#  'defunto': <gensim.models.keyedvectors.Vocab at 0x1e1c8098208>,
#  'argomento_bn:00005599n': <gensim.models.keyedvectors.Vocab at 0x1e1c8098240>,
#  'rinazionalizzazione': <gensim.models.keyedvectors.Vocab at 0x1e1c8098278>,
#  'gi\\xc3\\xa0_bn:00114423r': <gensim.models.keyedvectors.Vocab at 0x1e1c80982b0>,
#  'seppellire_bn:00084298v': <gensim.models.keyedvectors.Vocab at 0x1e1c80982e8>,
#  'livello_bn:00025966n': <gensim.models.keyedvectors.Vocab at 0x1e1c8098320>,
#  'contenuto_bn:00080229n': <gensim.models.keyedvectors.Vocab at 0x1e1c8098358>,
#  'leggere_bn:00092424v': <gensim.models.keyedvectors.Vocab at 0x1e1c8098390>,
#  'trattare_bn:00084527v': <gensim.models.keyedvectors.Vocab at 0x1e1c80983c8>,
#  'futuro_bn:00036942n': <gensim.models.keyedvectors.Vocab at 0x1e1c8098400>,
#  'alcuno': <gensim.models.keyedvectors.Vocab at 0x1e1c8098438>,
#  'scontro_bn:00009078n': <gensim.models.keyedvectors.Vocab at 0x1e1c8098470>,
#  'agenda': <gensim.models.keyedvectors.Vocab at 0x1e1c80984a8>,
#  '2000': <gensim.models.keyedvectors.Vocab at 0x1e1c80984e0>,
#  'questione': <gensim.models.keyedvectors.Vocab at 0x1e1c8098518>,
#  'contribuenti': <gensim.models.keyedvectors.Vocab at 0x1e1c8098550>,
#  'netti': <gensim.models.keyedvectors.Vocab at 0x1e1c8098588>,
#  'mettere_bn:00092204v': <gensim.models.keyedvectors.Vocab at 0x1e1c80985c0>,
#  'parentesi_bn:00006351n': <gensim.models.keyedvectors.Vocab at 0x1e1c80985f8>,
#  'potr\\xc3\\xa0': <gensim.models.keyedvectors.Vocab at 0x1e1c8098630>,
#  'momento_bn:00017621n': <gensim.models.keyedvectors.Vocab at 0x1e1c8098668>,
#  'ratificare_bn:00092379v': <gensim.models.keyedvectors.Vocab at 0x1e1c80986a0>,
#  'supporre_bn:00082872v': <gensim.models.keyedvectors.Vocab at 0x1e1c80986d8>,
#  'presidenza_bn:00064234n': <gensim.models.keyedvectors.Vocab at 0x1e1c8098710>,
#  'dispiacere_bn:00087029v': <gensim.models.keyedvectors.Vocab at 0x1e1c8098748>,
#  'vaso': <gensim.models.keyedvectors.Vocab at 0x1e1c8098780>,
#  'pandora': <gensim.models.keyedvectors.Vocab at 0x1e1c80987b8>,
#  'avr\\xc3\\xa0': <gensim.models.keyedvectors.Vocab at 0x1e1c80987f0>,
#  'scottare_bn:00084283v': <gensim.models.keyedvectors.Vocab at 0x1e1c8098828>,
#  'dito_bn:00024979n': <gensim.models.keyedvectors.Vocab at 0x1e1c8098860>,
#  'tema_bn:00074900n': <gensim.models.keyedvectors.Vocab at 0x1e1c8098898>,
#  'rovente_bn:00104348a': <gensim.models.keyedvectors.Vocab at 0x1e1c80988d0>,
#  'pertanto': <gensim.models.keyedvectors.Vocab at 0x1e1c8098908>,
#  'restare_bn:00085719v': <gensim.models.keyedvectors.Vocab at 0x1e1c8098940>,
#  'riguardo': <gensim.models.keyedvectors.Vocab at 0x1e1c8098978>,
#  'essere_bn:00088915v': <gensim.models.keyedvectors.Vocab at 0x1e1c80989b0>,
#  'riformare_bn:00092647v': <gensim.models.keyedvectors.Vocab at 0x1e1c80989e8>,
#  'punto_bn:00032425n': <gensim.models.keyedvectors.Vocab at 0x1e1c8098a20>,
#  'opportunit\\xc3\\xa0_bn:00017621n': <gensim.models.keyedvectors.Vocab at 0x1e1c8098a58>,
#  'dare_bn:00082442v': <gensim.models.keyedvectors.Vocab at 0x1e1c8098a90>,
#  'coraggio_bn:00011849n': <gensim.models.keyedvectors.Vocab at 0x1e1c8098ac8>,
#  'segnale_bn:00071525n': <gensim.models.keyedvectors.Vocab at 0x1e1c8098b00>,
#  'diventare': <gensim.models.keyedvectors.Vocab at 0x1e1c8098b38>,
#  'occasione_bn:00017621n': <gensim.models.keyedvectors.Vocab at 0x1e1c8098b70>,
#  'perduto_bn:00106186a': <gensim.models.keyedvectors.Vocab at 0x1e1c8098ba8>,
#  'considerare_bn:00085651v': <gensim.models.keyedvectors.Vocab at 0x1e1c8098be0>,
#  'perdita_bn:00052050n': <gensim.models.keyedvectors.Vocab at 0x1e1c8098c18>,
#  'credibilit\\xc3\\xa0_bn:00009718n': <gensim.models.keyedvectors.Vocab at 0x1e1c8098c50>,
#  'delusione_bn:00027430n': <gensim.models.keyedvectors.Vocab at 0x1e1c8098c88>,
#  'domanda_bn:00070389n': <gensim.models.keyedvectors.Vocab at 0x1e1c8098cc0>,
#  'scopo_bn:00030721n': <gensim.models.keyedvectors.Vocab at 0x1e1c8098cf8>,
#  'onorevole_bn:00102408a': <gensim.models.keyedvectors.Vocab at 0x1e1c8098d30>,
#  'collega_bn:00020118n': <gensim.models.keyedvectors.Vocab at 0x1e1c8098d68>,
#  'dipendere_bn:00086607v': <gensim.models.keyedvectors.Vocab at 0x1e1c8098da0>,
#  'probabilmente_bn:00114523r': <gensim.models.keyedvectors.Vocab at 0x1e1c8098dd8>,
#  'elemento_bn:00021394n': <gensim.models.keyedvectors.Vocab at 0x1e1c8098e10>,
#  'principale_bn:00099598a': <gensim.models.keyedvectors.Vocab at 0x1e1c8098e48>,
#  'primo_bn:00103232a': <gensim.models.keyedvectors.Vocab at 0x1e1c8098e80>,
#  'codificare_bn:00085251v': <gensim.models.keyedvectors.Vocab at 0x1e1c8098eb8>,
#  'convalidare_bn:00082434v': <gensim.models.keyedvectors.Vocab at 0x1e1c8098ef0>,
#  'consultazione_bn:00022092n': <gensim.models.keyedvectors.Vocab at 0x1e1c8098f28>,
#  'natura_bn:00057017n': <gensim.models.keyedvectors.Vocab at 0x1e1c8098f60>,
#  'contratto_bn:00022227n': <gensim.models.keyedvectors.Vocab at 0x1e1c8098f98>,
#  'base': <gensim.models.keyedvectors.Vocab at 0x1e1c8098fd0>,
#  'ideale_bn:00045804n': <gensim.models.keyedvectors.Vocab at 0x1e1c809c048>,
#  'professare_bn:00082637v': <gensim.models.keyedvectors.Vocab at 0x1e1c809c080>,
#  'chiarire_bn:00087826v': <gensim.models.keyedvectors.Vocab at 0x1e1c809c0b8>,
#  'ritrovare_bn:00088204v': <gensim.models.keyedvectors.Vocab at 0x1e1c809c0f0>,
#  'adesione_bn:00054282n': <gensim.models.keyedvectors.Vocab at 0x1e1c809c128>,
#  'europeo_bn:00031896n': <gensim.models.keyedvectors.Vocab at 0x1e1c809c160>,
#  'legittimare_bn:00090025v': <gensim.models.keyedvectors.Vocab at 0x1e1c809c198>,
#  'azione_bn:00016403n': <gensim.models.keyedvectors.Vocab at 0x1e1c809c1d0>,
#  ...}

# %%
senses_only_model = KeyedVectors.load_word2vec_format(embeddings_path, binary=False)
# Out:
# 2019-06-06 07:37:14,168 : INFO : loading projection weights from ../resources/ita_embeddings_size100_win6_neg20_lr0.09_epo10.vec
# 2019-06-06 07:37:14,170 : WARNING : this function is deprecated, use smart_open.open instead
# 2019-06-06 07:37:21,359 : INFO : loaded (34967, 100) matrix from ../resources/ita_embeddings_size100_win6_neg20_lr0.09_epo10.vec

# %%
print(len(senses_only_model.vocab))
# Out:
# 34967

# %% [markdown]
# ### Precision Data

# %%
embeddings_path = "../resources/ita_embeddings_prec_size{}_win{}_neg{}_lr{}_epo{}.vec".format(100, 6, 20, 0.09, 10)
model = Word2Vec(sentences_p, workers=5, size=100, window=6, alpha=0.09, negative=20, iter=10)

save_embeddings(embeddings_path, model.wv)
corr, p, data = score_it.spearman(test_data_path, embeddings_path, bn2wn_mapping_path)

# %%
print(corr)
print(len(model.wv.vocab))
# Out:
# 0.17436966517177743
# 100459

# %% [markdown]
# ### Coverage Data

# %%
embeddings_path = "../resources/ita_embeddings_cov_size{}_win{}_neg{}_lr{}_epo{}.vec".format(100, 6, 20, 0.09, 10)
model = Word2Vec(sentences_c, workers=5, size=100, window=6, alpha=0.09, negative=20, iter=10)

save_embeddings(embeddings_path, model.wv)
corr, p, data = score_it.spearman(test_data_path, embeddings_path, bn2wn_mapping_path)

# %%
print(corr)
print(len(model.wv.vocab))
# Out:
# 0.17436966517177743
# 89170

# %% [markdown]
# ## TSNE Plot

# %%
from gensim.models import KeyedVectors

embeddings_path = "../resources/ita_embeddings_size{}_win{}_neg{}_lr{}_epo{}.vec".format(100, 6, 20, 0.09, 10)
model = KeyedVectors.load_word2vec_format(embeddings_path, binary=False)

# %%
model.most_similar("credere_bn:00083369v", topn=10)
# Out:
# [('credere_bn:00089105v', 0.823046863079071),
#  ('credere_bn:00083370v', 0.7933206558227539),
#  ('convincere_bn:00085767v', 0.7707583904266357),
#  ('credere_bn:00088095v', 0.7553455829620361),
#  ('credere_bn:00083371v', 0.7368806004524231),
#  ('pensare_bn:00087737v', 0.7334431409835815),
#  ('ritenere_bn:00086435v', 0.7329109311103821),
#  ('credere_bn:00083373v', 0.7313423752784729),
#  ('pensare_bn:00084733v', 0.7283991575241089),
#  ('convincere_bn:00084573v', 0.7256429195404053)]

# %%
from sklearn.manifold import TSNE
import numpy as np

keys = ['credere_bn:00083369v', 'estremamente_bn:00115271r', 'importante_bn:00104681a', 'ridurre_bn:00086418v', 'zona_bn:00005513n']

embedding_clusters = []
word_clusters = []
for word in keys:
    embeddings = []
    words = []
    for similar_word, _ in model.most_similar(word, topn=20):
        words.append(similar_word)
        embeddings.append(model[similar_word])
    embedding_clusters.append(embeddings)
    word_clusters.append(words)
    
embedding_clusters = np.array(embedding_clusters)
n, m, k = embedding_clusters.shape
tsne_model_en_2d = TSNE(perplexity=15, n_components=2, init='pca', n_iter=3500, random_state=32)
embeddings_en_2d = np.array(tsne_model_en_2d.fit_transform(embedding_clusters.reshape(n * m, k))).reshape(n, m, 2)

# %%
tsne_similar_words_plot('Similar words to some randomly selected sense embeddings', keys, embeddings_en_2d, word_clusters, 0.7, 'similar_words.png')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
