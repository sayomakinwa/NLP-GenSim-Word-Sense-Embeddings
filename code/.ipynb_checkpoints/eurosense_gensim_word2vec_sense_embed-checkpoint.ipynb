# %% [markdown]
# ## Imports, as always!

# %%
import logging
from gensim.models import Word2Vec
import numpy as np
import matplotlib.pyplot as plt

from corpora import *
from my_utils import *
import score

# %% [markdown]
# ## Parsing Corpora

# %%
corpora_path = '../EuroSense/eurosense.v1.0.high-precision.xml'
bn2wn_mapping_path = '../resources/bn2wn_mapping.txt'
outfile_path = './EuroSense/parsed_lower/sentences_precision.txt'

parse(corpora_path, bn2wn_mapping_path, outfile_path, "precision")
#1,903,116 sentences
# Out:
# 1,903,116 sentences extracted...
# Done!

# %%
corpora_path = '../EuroSense/EuroSense/eurosense.v1.0.high-coverage.xml'
bn2wn_mapping_path = '../resources/bn2wn_mapping.txt'
outfile_path = '../EuroSense/parsed_lower/sentenses_coverage.txt'

parse(corpora_path, bn2wn_mapping_path, outfile_path, "coverage")
#1,903,181 sentences

# %%
bn2wn_mapping_path = '../resources/bn2wn_mapping.txt'
sentences_p = InputSentences('../EuroSense/parsed_low_stp/sentences_precision.txt')
sentences_c = InputSentences('../EuroSense/parsed_low_stp/sentences_coverage.txt')
sentences_folder = InputSentences('../EuroSense/parsed_low_stp/')
test_data_path = "../wordsim353/combined.tab"

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# ## Training the Model; Parameter Tuning
#
# All tunings are done with the following parameters:
#
# dataset = precision; min_count = 5; workers = 5; score for words not found = -1

# %% [markdown]
# ### 1. Tuning 'window'
# size = 400 (from the reference paper); alpha = 0.025; iter = 5 (default)

# %%
windows = [3, 5, 6, 8, 10]
correlations = []
pvals = []

# %%
for windw in windows:
    embeddings_path = "../resources/embeddings_win{}.vec".format(windw)
    
    model_win = Word2Vec(sentences_p, size=400, workers=5, window=windw)
    save_embeddings(embeddings_path, model_win.wv)
    
    corr, p, data = score.spearman(test_data_path, embeddings_path)
    correlations.append(corr)
    pvals.append(p)

# %%
del model_win
fig = plt.gcf()
fig.set_size_inches(8.5, 3)

plt.subplot(1, 2, 1)
plt.plot(windows, correlations, 'b')
plt.xlabel('Window')
plt.ylabel('Correlation')
plt.title("Correlation graph")
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(windows, pvals, 'r')
plt.xlabel('Window')
plt.ylabel('p-value')
plt.title("p-value graph")
plt.grid()

plt.tight_layout()
plt.show()

print(correlations)
print(pvals)
# Out:
# [0.26100232563012454]
# [6.597456085045413e-07]

# %% [markdown]
# ### 2. High precision corpus vs High coverage corpus vs Combined (not uniquely)
# window = 6; size = 400 (from the reference paper); alpha = 0.025; iter = 5 (default)

# %%
names = ["Precision", "Coverage", "Combined"]
correlations = []
pvals = []

# %%
embeddings_path = "../resources/embeddings_precision.vec"
model_precision = Word2Vec(sentences_p, size=400, workers=5, window=6)
save_embeddings(embeddings_path, model_precision.wv)

corr, p, data = score.spearman(test_data_path, embeddings_path)
correlations.append(corr)
pvals.append(p)
#=========================================
embeddings_path = "../resources/embeddings_coverage.vec"
model_coverage = Word2Vec(sentences_c, size=400, workers=5, window=6)
save_embeddings(embeddings_path, model_coverage.wv)

corr, p, data = score.spearman(test_data_path, embeddings_path)
correlations.append(corr)
pvals.append(p)
#=========================================
embeddings_path = "../resources/embeddings_combined.vec"
model_comb = Word2Vec(sentences_folder, size=400, workers=5, window=6)
save_embeddings(embeddings_path, model_comb.wv)

corr, p, data = score.spearman(test_data_path, embeddings_path)
correlations.append(corr)
pvals.append(p)

# %%
print("Vocab size for high precision data is: {:,d}".format(len(model_precision.wv.vocab)))
print("Vocab size for high coverage data is: {:,d}".format(len(model_coverage.wv.vocab)))
print("Vocab size for the combined data is: {:,d}".format(len(model_comb.wv.vocab)))

del model_precision
del model_coverage
del model_comb
# Out:
# Vocab size for high precision data is: 61,693
# Vocab size for high coverage data is: 60,933
# Vocab size for the combined data is: 86,482

# %%
bar_width = 0.3
pos1 = np.arange(len(correlations))
pos2 = [x + bar_width for x in pos1]

fig = plt.gcf()
fig.set_size_inches(8, 3)

plt.subplot(1, 2, 1)
plt.bar(pos1, correlations, color='blue', width=bar_width)
plt.title("Correlation graph")
plt.xticks([y for y in range(len(correlations))], names)
plt.grid()

plt.subplot(1, 2, 2)
plt.bar(pos2, _pvals, color='red', width=bar_width)
plt.title("p-value graph")
plt.xticks([y + bar_width for y in range(len(correlations))], names)
plt.grid()

plt.tight_layout()
plt.show()

print(correlations)
print(pvals)
# Out:
# [0.1328997636846252, 0.16103731239116484, 0.17566626310041306]
# [0.012447440842243446, 0.0024076274352001934, 0.0009178285065600792]

# %% [markdown]
# ### 3. Tuning vector 'size'
# window = 6; alpha = 0.025; iter = 5 (default); combined dataset

# %%
sizes = [100, 200, 300, 400, 500, 600]
correlations = []
pvals = []

# %%
for s in sizes:
    embeddings_path = "../resources/embeddings_size{}.vec".format(s)
    
    model_size = Word2Vec(sentences_folder, workers=5, size=s, window=6)
    save_embeddings(embeddings_path, model_size.wv)
    
    corr, p, data = score.spearman(test_data_path, embeddings_path)
    correlations.append(corr)
    pvals.append(p)

# %%
del model_size
fig = plt.gcf()
fig.set_size_inches(8.5, 3)

plt.subplot(1, 2, 1)
plt.plot(sizes, correlations, 'b')
plt.xlabel('Vector sizes')
plt.ylabel('Correlation')
plt.title("Correlation graph for vector 'size'")
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(sizes, pvals, 'r')
plt.xlabel('Vector sizes')
plt.ylabel('p-value')
plt.title("p-value graph for vector 'size'")
plt.grid()

plt.tight_layout()
plt.show()

print(correlations)
print(pvals)
# Out:
# [0.18482882260978845, 0.17081055797772945, 0.1644249983301631, 0.17447065509094467, 0.18812549418747526, 0.16793873273427085]
# [0.00048226052458377565, 0.0012749327144777407, 0.0019389377650786733, 0.0009959758304877936, 0.00037970453160762627, 0.0015422694092686938]

# %% [markdown]
# ### 4.1. Tuning starting 'alpha'
# size = 500; window = 6; iter = 5 (default)

# %%
alphas = [0.02, 0.04, 0.06, 0.08, 0.1]
correlations = []
pvals = []

# %%
for alph in alphas:
    embeddings_path = "../resources/embeddings_alpha{}.vec".format(alph)
    
    model_alph = Word2Vec(sentences_folder, workers=5, size=500, window=6, alpha=alph)
    save_embeddings(embeddings_path, model_alph.wv)
    
    corr, p, data = score.spearman(test_data_path, embeddings_path)
    correlations.append(corr)
    pvals.append(p)

# %%
alphas = [0.02, 0.04, 0.06, 0.08, 0.1]
_correlations = []
_pvals = []

# %%
del model_alph

fig = plt.gcf()
fig.set_size_inches(8.5, 3)

plt.subplot(1, 2, 1)
plt.plot(alphas, correlations, 'b')
plt.xlabel('Alpha')
plt.ylabel('Correlation')
plt.title("Correlation graph for alpha")
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(alphas, pvals, 'r')
plt.xlabel('Alpha')
plt.ylabel('p-value')
plt.title("p-value graph for alpha")
plt.grid()

plt.tight_layout()
plt.show()

print(correlations)
print(pvals)
# Out:
# [0.26100232563012454]
# [6.597456085045413e-07]

# %% [markdown]
# ### 4.2. Tuning starting 'alpha'
# size = 500; window = 6; iter = 5 (default)

# %%
alphas = [0.005, 0.007, 0.009, 0.01, 0.02]
correlations = []
pvals = []

# %%
for alph in alphas:
    embeddings_path = "../resources/embeddings_alpha{}.vec".format(alph)
    
    model_alph = Word2Vec(sentences_folder, workers=5, size=500, window=6, alpha=alph)
    save_embeddings(embeddings_path, model_alph.wv)
    
    corr, p, data = score.spearman(test_data_path, embeddings_path)
    correlations.append(corr)
    pvals.append(p)

# %%
#del model_alph

fig = plt.gcf()
fig.set_size_inches(8.5, 3)

plt.subplot(1, 2, 1)
plt.plot(alphas, correlations, 'b')
plt.xlabel('Alpha')
plt.ylabel('Correlation')
plt.title("Correlation graph for alpha")
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(alphas, pvals, 'r')
plt.xlabel('Alpha')
plt.ylabel('p-value')
plt.title("p-value graph for alpha")
plt.grid()

plt.tight_layout()
plt.show()

print(correlations)
print(pvals)
# Out:
# [-0.02271037008346432, -0.012308103696220136, 0.005739443758655788, 0.02007408333515987, 0.12138840404542614]
# [0.6706686095111363, 0.8177523699985041, 0.9144297926764244, 0.7070225137185358, 0.022546492097061666]

# %% [markdown]
# ### 5. Tuning epochs 'iter'
# alpha = 0.009; size = 500; window = 6;

# %%
epochs = [30]
correlations = []
pvals = []

# %%
for epoch in epochs:
    embeddings_path = "../resources/embeddings_epochs{}.vec".format(epoch)
    
    model_iter = Word2Vec(sentences_folder, workers=5, size=500, window=6, iter=epoch)
    save_embeddings(embeddings_path, model_iter.wv)
    
    corr, p, data = score.spearman(test_data_path, embeddings_path)
    correlations.append(corr)
    pvals.append(p)

# %%
correlations
# Out:
# [0.2448334698902266]

# %%
#epochs = [40, 50]

epochs = [30]
# correlations = []
# pvals = []

model_iter = Word2Vec(sentences_folder, workers=5, size=500, window=6, alpha=0.03, iter=30)
save_embeddings(embeddings_path, model_iter.wv)

corr, p, data = score.spearman(test_data_path, embeddings_path)
correlations.append(corr)
pvals.append(p)

# %%
print(embeddings_path)
for epoch in epochs:
    embeddings_path = "../resources/embeddings_epochs{}.vec".format(epoch)
    
    model_iter = Word2Vec(sentences_folder, workers=5, size=500, window=6, iter=epoch)
    save_embeddings(embeddings_path, model_iter.wv)
    
    corr, p, data = score.spearman(test_data_path, embeddings_path)
    correlations.append(corr)
    pvals.append(p)

# %%
# del model_iter

# plt.plot(alphas, correlations, 'b', alphas, pvals, 'r')
# plt.xlabel('Epochs')
# plt.text(45, .135, 'Correlation')
# plt.text(48, .008, 'p-value')
# plt.show()

correlations
# Out:
# [0.2448334698902266, 0.22689783999291746, 0.24666968641661396]

# %%
correlations = []
pvals = []

# embeddings_path = "../resources/embeddings_size{}_lr{}_epo{}.vec".format(100, 0.045, 10)

# model_iter = Word2Vec(sentences_folder, workers=5, size=100, window=6, alpha=0.045, iter=10)
# save_embeddings(embeddings_path, model_iter.wv)

# corr, p, data = score.spearman(test_data_path, embeddings_path)
# correlations.append(corr)
# pvals.append(p)


embeddings_path = "../resources/embeddings_prec_size{}_win{}_neg{}_lr{}_epo{}.vec".format(100, 6, 20, 0.09, 10)

model_iter = Word2Vec(sentences_p, workers=5, size=100, window=6, alpha=0.09, negative=20, iter=10)
save_embeddings(embeddings_path, model_iter.wv)

corr, p, data = score.spearman(test_data_path, embeddings_path)
correlations.append(corr)
pvals.append(p)

# %%
print(len(model_iter.wv.vocab))
# Out:
# 88788

# %%
senses_only_model = KeyedVectors.load_word2vec_format(embeddings_path, binary=False)
# Out:
# 2019-06-06 07:41:24,969 : INFO : loading projection weights from ../resources/embeddings_size100_win6_neg20_lr0.09_epo10.vec
# 2019-06-06 07:41:24,970 : WARNING : this function is deprecated, use smart_open.open instead
# 2019-06-06 07:41:45,122 : INFO : loaded (37875, 100) matrix from ../resources/embeddings_size100_win6_neg20_lr0.09_epo10.vec

# %%
print(len(senses_only_model.vocab))
# Out:
# 37875

# %%
correlations
# Out:
# [0.18799345626018882]

# %%
data
# Out:
# [['love', 'sex', '6.77', 0.5506521],
#  ['tiger', 'cat', '7.35', 0.31482702],
#  ['tiger', 'tiger', '10.00', 1.0],
#  ['book', 'paper', '7.46', 0.59138244],
#  ['computer', 'keyboard', '7.62', -1.0],
#  ['computer', 'internet', '7.58', 0.68330854],
#  ['plane', 'car', '5.77', 0.5530336],
#  ['train', 'car', '6.31', 0.5517221],
#  ['telephone', 'communication', '7.50', 0.40216556],
#  ['television', 'radio', '6.77', 0.7742272],
#  ['media', 'radio', '7.42', 0.57902765],
#  ['drug', 'abuse', '6.85', 0.45984665],
#  ['bread', 'butter', '6.19', 0.53301316],
#  ['cucumber', 'potato', '5.92', 0.41685078],
#  ['doctor', 'nurse', '7.00', 0.76823616],
#  ['professor', 'doctor', '6.62', 0.5231342],
#  ['student', 'professor', '6.81', 0.5513499],
#  ['smart', 'student', '4.62', 0.397799],
#  ['smart', 'stupid', '5.81', 0.47028974],
#  ['company', 'stock', '7.08', 0.4895719],
#  ['stock', 'market', '8.08', 0.54279566],
#  ['stock', 'phone', '1.62', 0.5188834],
#  ['stock', 'CD', '1.31', 0.39869478],
#  ['stock', 'jaguar', '0.92', -1.0],
#  ['stock', 'egg', '1.81', 0.50456196],
#  ['fertility', 'egg', '6.69', 0.28806856],
#  ['stock', 'live', '3.73', 0.5159809],
#  ['stock', 'life', '0.92', 0.4656124],
#  ['book', 'library', '7.46', 0.6346239],
#  ['bank', 'money', '8.12', 0.4024241],
#  ['wood', 'forest', '7.73', 1.0000001],
#  ['money', 'cash', '9.15', 0.6318514],
#  ['professor', 'cucumber', '0.31', 0.22720537],
#  ['king', 'cabbage', '0.23', 0.38063478],
#  ['king', 'queen', '8.58', 1.0000001],
#  ['king', 'rook', '5.92', 0.3713036],
#  ['bishop', 'rabbi', '6.69', -1.0],
#  ['Jerusalem', 'Israel', '8.46', -1.0],
#  ['Jerusalem', 'Palestinian', '7.65', -1.0],
#  ['holy', 'sex', '1.62', 0.273747],
#  ['fuck', 'sex', '9.44', 0.3505253],
#  ['Maradona', 'football', '8.62', -1.0],
#  ['football', 'soccer', '9.03', 0.17379057],
#  ['football', 'basketball', '6.81', 0.13241616],
#  ['football', 'tennis', '6.63', -0.023953484],
#  ['tennis', 'racket', '7.56', 0.11414926],
#  ['Arafat', 'peace', '6.73', -1.0],
#  ['Arafat', 'terror', '7.65', -1.0],
#  ['Arafat', 'Jackson', '2.50', -1.0],
#  ['law', 'lawyer', '8.38', 0.43127394],
#  ['movie', 'star', '7.38', 0.4357351],
#  ['movie', 'popcorn', '6.19', -1.0],
#  ['movie', 'critic', '6.73', 0.3369772],
#  ['movie', 'theater', '7.92', 0.5140897],
#  ['physics', 'proton', '8.12', -1.0],
#  ['physics', 'chemistry', '7.35', 0.3790897],
#  ['space', 'chemistry', '4.88', 0.2743943],
#  ['alcohol', 'chemistry', '5.54', 0.26737216],
#  ['vodka', 'gin', '8.46', 0.4908893],
#  ['vodka', 'brandy', '8.13', 0.4966406],
#  ['drink', 'car', '3.04', 0.37131327],
#  ['drink', 'ear', '1.31', 0.30733946],
#  ['drink', 'mouth', '5.96', 0.37683412],
#  ['drink', 'eat', '6.87', 0.65532875],
#  ['baby', 'mother', '7.85', 0.6743757],
#  ['drink', 'mother', '2.65', 0.42418444],
#  ['car', 'automobile', '8.94', 1.0000001],
#  ['gem', 'jewel', '8.96', 1.0000001],
#  ['journey', 'voyage', '9.29', 0.47336665],
#  ['boy', 'lad', '8.83', 0.4464381],
#  ['coast', 'shore', '9.10', 0.7077514],
#  ['asylum', 'madhouse', '8.87', -1.0],
#  ['magician', 'wizard', '9.02', 1.0],
#  ['midday', 'noon', '9.29', 1.0000001],
#  ['furnace', 'stove', '8.79', 0.32763043],
#  ['food', 'fruit', '7.52', 0.3796612],
#  ['bird', 'cock', '7.10', 0.338404],
#  ['bird', 'crane', '7.38', 0.3858083],
#  ['tool', 'implement', '6.46', 0.364645],
#  ['brother', 'monk', '6.27', 0.35732666],
#  ['crane', 'implement', '2.69', 0.17697439],
#  ['lad', 'brother', '4.46', 0.36142194],
#  ['journey', 'car', '5.85', 0.38143262],
#  ['monk', 'oracle', '5.00', 0.20564239],
#  ['cemetery', 'woodland', '2.08', 0.30470783],
#  ['food', 'rooster', '4.42', 0.11336098],
#  ['coast', 'hill', '4.38', 0.36160412],
#  ['forest', 'graveyard', '1.85', 0.34384665],
#  ['shore', 'woodland', '3.08', 0.60201],
#  ['monk', 'slave', '0.92', 0.25095022],
#  ['coast', 'forest', '3.15', 0.47395808],
#  ['lad', 'wizard', '0.92', 0.34948868],
#  ['chord', 'smile', '0.54', 0.17000832],
#  ['glass', 'magician', '2.08', 0.2846896],
#  ['noon', 'string', '0.54', 0.24350117],
#  ['rooster', 'voyage', '0.62', 0.2527586],
#  ['money', 'dollar', '8.42', 0.4741762],
#  ['money', 'cash', '9.08', 0.6318514],
#  ['money', 'currency', '9.04', 0.21690667],
#  ['money', 'wealth', '8.27', 0.37106737],
#  ['money', 'property', '7.57', 0.37216648],
#  ['money', 'possession', '7.29', 0.20470001],
#  ['money', 'bank', '8.50', 0.4024241],
#  ['money', 'deposit', '7.73', 0.4024241],
#  ['money', 'withdrawal', '6.88', 0.15003438],
#  ['money', 'laundering', '5.65', 0.30059084],
#  ['money', 'operation', '3.31', 0.3321704],
#  ['tiger', 'jaguar', '8.00', -1.0],
#  ['tiger', 'feline', '8.00', 0.1322835],
#  ['tiger', 'carnivore', '7.08', 0.18468973],
#  ['tiger', 'mammal', '6.85', 0.21213402],
#  ['tiger', 'animal', '7.00', 0.2561056],
#  ['tiger', 'organism', '4.77', 0.16684456],
#  ['tiger', 'fauna', '5.62', 0.2561056],
#  ['tiger', 'zoo', '5.87', 0.08345791],
#  ['psychology', 'psychiatry', '8.08', 0.2580191],
#  ['psychology', 'anxiety', '7.00', 0.26350087],
#  ['psychology', 'fear', '6.85', 0.32854593],
#  ['psychology', 'depression', '7.42', 0.27163836],
#  ['psychology', 'clinic', '6.58', 0.17201439],
#  ['psychology', 'doctor', '6.42', 0.2653518],
#  ['psychology', 'Freud', '8.21', -1.0],
#  ['psychology', 'mind', '7.69', 0.32941684],
#  ['psychology', 'health', '7.23', 0.23319979],
#  ['psychology', 'science', '6.71', 0.32897756],
#  ['psychology', 'discipline', '5.58', 0.38233456],
#  ['psychology', 'cognition', '7.48', 0.20934686],
#  ['planet', 'star', '8.45', 0.37225118],
#  ['planet', 'constellation', '8.06', 0.45657298],
#  ['planet', 'moon', '8.08', 0.35279965],
#  ['planet', 'sun', '8.02', 0.36493784],
#  ['planet', 'galaxy', '8.11', 0.36086902],
#  ['planet', 'space', '7.92', 0.5186],
#  ['planet', 'astronomer', '7.94', 0.47791132],
#  ['precedent', 'example', '5.85', 0.54519796],
#  ['precedent', 'information', '3.85', 0.13656959],
#  ['precedent', 'cognition', '2.81', 0.17707354],
#  ['precedent', 'law', '6.65', 0.26895759],
#  ['precedent', 'collection', '2.50', 0.26078278],
#  ['precedent', 'group', '1.77', 0.25031292],
#  ['precedent', 'antecedent', '6.04', 0.19819868],
#  ['cup', 'coffee', '6.58', 0.5007863],
#  ['cup', 'tableware', '6.85', -1.0],
#  ['cup', 'article', '2.40', 0.22669406],
#  ['cup', 'artifact', '2.92', 0.23745973],
#  ['cup', 'object', '3.69', 0.27942836],
#  ['cup', 'entity', '2.15', 0.1328646],
#  ['cup', 'drink', '7.25', 0.37487823],
#  ['cup', 'food', '5.00', 0.2716837],
#  ['cup', 'substance', '1.92', 0.3664848],
#  ['cup', 'liquid', '5.90', 0.3097304],
#  ['jaguar', 'cat', '7.42', -1.0],
#  ['jaguar', 'car', '7.27', -1.0],
#  ['energy', 'secretary', '1.81', 0.3403957],
#  ['secretary', 'senate', '5.06', 0.23221007],
#  ['energy', 'laboratory', '5.09', 0.23928669],
#  ['computer', 'laboratory', '6.78', 0.41678378],
#  ['weapon', 'secret', '6.06', 0.3894571],
#  ['FBI', 'fingerprint', '6.94', -1.0],
#  ['FBI', 'investigation', '8.31', -1.0],
#  ['investigation', 'effort', '4.59', 0.37407458],
#  ['Mars', 'water', '2.94', 0.41683474],
#  ['Mars', 'scientist', '5.63', 0.14095183],
#  ['news', 'report', '8.16', 0.55220956],
#  ['canyon', 'landscape', '7.53', 0.2301705],
#  ['image', 'surface', '4.56', 0.7051097],
#  ['discovery', 'space', '6.34', 0.4129824],
#  ['water', 'seepage', '6.56', -1.0],
#  ['sign', 'recess', '2.38', 0.46398327],
#  ['Wednesday', 'news', '2.22', -1.0],
#  ['mile', 'kilometer', '8.66', 0.7769118],
#  ['computer', 'news', '4.47', 0.3321797],
#  ['territory', 'surface', '5.34', 0.5155384],
#  ['atmosphere', 'landscape', '3.69', 0.36938092],
#  ['president', 'medal', '3.00', 0.2841251],
#  ['war', 'troops', '8.13', 0.45022932],
#  ['record', 'number', '6.31', 0.6356079],
#  ['skin', 'eye', '6.22', 0.39153475],
#  ['Japanese', 'American', '6.50', -1.0],
#  ['theater', 'history', '3.91', 0.39969802],
#  ['volunteer', 'motto', '2.56', 0.2934265],
#  ['prejudice', 'recognition', '3.00', 0.36608705],
#  ['decoration', 'valor', '5.63', 0.22982906],
#  ['century', 'year', '7.59', 0.6189611],
#  ['century', 'nation', '3.16', 0.3605578],
#  ['delay', 'racism', '1.19', 0.3467542],
#  ['delay', 'news', '3.31', 0.348617],
#  ['minister', 'party', '6.63', 0.22920996],
#  ['peace', 'plan', '4.75', 0.29857114],
#  ['minority', 'peace', '3.69', 0.1980942],
#  ['attempt', 'peace', '4.25', 0.4394067],
#  ['government', 'crisis', '6.56', 0.29885584],
#  ['deployment', 'departure', '4.25', 0.46307182],
#  ['deployment', 'withdrawal', '5.88', 0.58727956],
#  ['energy', 'crisis', '5.94', 0.2309701],
#  ['announcement', 'news', '7.56', 0.43272072],
#  ['announcement', 'effort', '2.75', 0.44040844],
#  ['stroke', 'hospital', '7.03', 0.39707825],
#  ['disability', 'death', '5.47', 0.38932693],
#  ['victim', 'emergency', '6.47', 0.28331855],
#  ['treatment', 'recovery', '7.91', 0.3943818],
#  ['journal', 'association', '4.97', 0.30573526],
#  ['doctor', 'personnel', '5.00', 0.4045318],
#  ['doctor', 'liability', '5.19', 0.3623611],
#  ['liability', 'insurance', '7.03', 0.5543284],
#  ['school', 'center', '3.44', 0.44669417],
#  ['reason', 'hypertension', '2.31', 0.23246408],
#  ['reason', 'criterion', '5.91', 0.38843885],
#  ['hundred', 'percent', '7.38', 0.35487312],
#  ['Harvard', 'Yale', '8.13', -1.0],
#  ['hospital', 'infrastructure', '4.63', 0.36358893],
#  ['death', 'row', '5.25', 0.4336643],
#  ['death', 'inmate', '5.03', 0.4013806],
#  ['lawyer', 'evidence', '6.69', 0.3567697],
#  ['life', 'death', '7.88', 0.46839553],
#  ['life', 'term', '4.50', 0.51316446],
#  ['word', 'similarity', '4.75', 0.29316247],
#  ['board', 'recommendation', '4.47', 0.5193547],
#  ['governor', 'interview', '3.25', 0.39301616],
#  ['OPEC', 'country', '5.63', -1.0],
#  ['peace', 'atmosphere', '3.69', 0.36422226],
#  ['peace', 'insurance', '2.94', 0.1746339],
#  ['territory', 'kilometer', '5.28', 0.36287948],
#  ['travel', 'activity', '5.00', 0.3418212],
#  ['competition', 'price', '6.44', 0.39019957],
#  ['consumer', 'confidence', '4.13', 0.32814288],
#  ['consumer', 'energy', '4.75', 0.31671742],
#  ['problem', 'airport', '2.38', 0.23347256],
#  ['car', 'flight', '4.94', 0.39035454],
#  ['credit', 'card', '8.06', 0.5124717],
#  ['credit', 'information', '5.31', 0.45686218],
#  ['hotel', 'reservation', '8.03', 0.50388855],
#  ['grocery', 'money', '5.94', 0.3008607],
#  ['registration', 'arrangement', '6.00', 0.47058722],
#  ['arrangement', 'accommodation', '5.41', 0.47058722],
#  ['month', 'hotel', '1.81', 0.27885452],
#  ['type', 'kind', '8.97', 0.6866405],
#  ['arrival', 'hotel', '6.00', 0.28197324],
#  ['bed', 'closet', '6.72', 0.43277487],
#  ['closet', 'clothes', '8.00', 0.45159915],
#  ['situation', 'conclusion', '4.81', 0.5072273],
#  ['situation', 'isolation', '3.88', 0.4194484],
#  ['impartiality', 'interest', '5.16', 0.27899477],
#  ['direction', 'combination', '2.25', 0.3773184],
#  ['street', 'place', '6.44', 0.4576299],
#  ['street', 'avenue', '8.88', 0.2511484],
#  ['street', 'block', '6.88', 0.4234309],
#  ['street', 'children', '4.94', 0.37506342],
#  ['listing', 'proximity', '2.56', 0.25243577],
#  ['listing', 'category', '6.38', 0.4059426],
#  ['cell', 'phone', '7.81', 0.41760072],
#  ['production', 'hike', '1.75', 0.4583474],
#  ['benchmark', 'index', '4.25', 0.5625997],
#  ['media', 'trading', '3.88', 0.48290995],
#  ['media', 'gain', '2.88', 0.4578353],
#  ['dividend', 'payment', '7.63', 0.30883726],
#  ['dividend', 'calculation', '6.48', 0.2851365],
#  ['calculation', 'computation', '8.44', 1.0000001],
#  ['currency', 'market', '7.50', 0.53485715],
#  ['OPEC', 'oil', '8.59', -1.0],
#  ['oil', 'stock', '6.34', 0.506864],
#  ['announcement', 'production', '3.38', 0.27250966],
#  ['announcement', 'warning', '6.00', 0.3560744],
#  ['profit', 'warning', '3.88', 0.561384],
#  ['profit', 'loss', '7.63', 0.6119296],
#  ['dollar', 'yen', '7.78', 0.513145],
#  ['dollar', 'buck', '9.22', 1.0000002],
#  ['dollar', 'profit', '7.38', 0.36895254],
#  ['dollar', 'loss', '6.09', 0.3900644],
#  ['computer', 'software', '8.50', 0.6260886],
#  ['network', 'hardware', '8.31', 0.3532024],
#  ['phone', 'equipment', '7.13', 0.4528687],
#  ['equipment', 'maker', '5.91', 0.4270501],
#  ['luxury', 'car', '6.47', 0.4098066],
#  ['five', 'month', '3.38', 0.15317193],
#  ['report', 'gain', '3.63', 0.5446266],
#  ['investor', 'earning', '7.13', 0.45772582],
#  ['liquid', 'water', '7.89', 0.47915775],
#  ['baseball', 'season', '5.97', 0.31095555],
#  ['game', 'victory', '7.03', 0.34038037],
#  ['game', 'team', '7.69', 0.2948599],
#  ['marathon', 'sprint', '7.47', 0.33570254],
#  ['game', 'series', '6.19', 0.26859984],
#  ['game', 'defeat', '6.97', 0.4997018],
#  ['seven', 'series', '3.56', 0.19237186],
#  ['seafood', 'sea', '7.47', 0.35690778],
#  ['seafood', 'food', '8.34', 0.45203018],
#  ['seafood', 'lobster', '8.70', 0.42723858],
#  ['lobster', 'food', '7.81', 0.24837266],
#  ['lobster', 'wine', '5.70', 0.31486613],
#  ['food', 'preparation', '6.22', 0.458887],
#  ['video', 'archive', '6.34', 0.50068974],
#  ['start', 'year', '4.06', 0.3799483],
#  ['start', 'match', '4.47', 0.48789173],
#  ['game', 'round', '5.97', 0.48567015],
#  ['boxing', 'round', '7.61', 0.43320236],
#  ['championship', 'tournament', '8.36', 0.5708513],
#  ['fighting', 'defeating', '7.41', 0.72607],
#  ['line', 'insurance', '2.69', 0.33898634],
#  ['day', 'summer', '3.94', 0.57008713],
#  ['summer', 'drought', '7.16', 0.5139509],
#  ['summer', 'nature', '5.63', 0.12927096],
#  ['day', 'dawn', '7.53', 0.6933783],
#  ['nature', 'environment', '8.31', 0.34410682],
#  ['environment', 'ecology', '8.81', 0.3026659],
#  ['nature', 'man', '6.25', 0.3122118],
#  ['man', 'woman', '8.30', 0.81786805],
#  ['man', 'governor', '5.25', 0.32550463],
#  ['murder', 'manslaughter', '8.53', 0.4600605],
#  ['soap', 'opera', '7.94', 0.4805469],
#  ['opera', 'performance', '6.88', 0.3387543],
#  ['life', 'lesson', '5.94', 0.39934802],
#  ['focus', 'life', '4.06', 0.4691337],
#  ['production', 'crew', '6.25', 0.3428555],
#  ['television', 'film', '7.72', 0.682807],
#  ['lover', 'quarrel', '6.19', 0.34037787],
#  ['viewer', 'serial', '2.97', 0.30333188],
#  ['possibility', 'girl', '1.94', 0.24062519],
#  ['population', 'development', '3.75', 0.34518206],
#  ['morality', 'importance', '3.31', 0.14936009],
#  ['morality', 'marriage', '3.69', 0.23693618],
#  ['Mexico', 'Brazil', '7.44', -1.0],
#  ['gender', 'equality', '6.41', 0.51034373],
#  ['change', 'attitude', '5.44', 0.45742458],
#  ['family', 'planning', '6.25', 0.40946823],
#  ['opera', 'industry', '2.63', 0.29631922],
#  ['sugar', 'approach', '0.88', 0.37325114],
#  ['practice', 'institution', '3.19', 0.4283856],
#  ['ministry', 'culture', '4.69', 0.1993227],
#  ['problem', 'challenge', '6.75', 0.6531488],
#  ['size', 'prominence', '5.31', 0.3566163],
#  ['country', 'citizen', '7.31', 0.44546524],
#  ['planet', 'people', '5.75', 0.35695776],
#  ['development', 'issue', '3.97', 0.54159415],
#  ['experience', 'music', '3.47', 0.37709352],
#  ['music', 'project', '3.63', 0.37709352],
#  ['glass', 'metal', '5.56', 0.46975368],
#  ['aluminum', 'metal', '7.83', 0.64639175],
#  ['chance', 'credibility', '3.88', 0.3104618],
#  ['exhibit', 'memorabilia', '5.31', -1.0],
#  ['concert', 'virtuoso', '6.81', 0.33608288],
#  ['rock', 'jazz', '7.59', 0.498605],
#  ['museum', 'theater', '7.19', 0.5763178],
#  ['observation', 'architecture', '4.38', 0.27400014],
#  ['space', 'world', '6.53', 0.4995106],
#  ['preservation', 'world', '6.19', 0.47658357],
#  ['admission', 'ticket', '7.69', 0.3343863],
#  ['shower', 'thunderstorm', '6.31', -1.0],
#  ['shower', 'flood', '6.03', 0.33931538],
#  ['weather', 'forecast', '8.34', 0.4440804],
#  ['disaster', 'area', '6.25', 0.36068073],
#  ['governor', 'office', '6.34', 0.5134456],
#  ['architecture', 'century', '3.78', 0.30528247]]

# %% [markdown]
# ## TSNE Plots

# %%
from gensim.models import KeyedVectors

#embeddings_path = "../resources/embeddings_size100_win6_neg20_lr0.09_epo10.vec"
embeddings_path = "../resources/embeddings_size100_win6_neg5_lr0.09_epo10.vec"
model = KeyedVectors.load_word2vec_format(embeddings_path, binary=False)
# Out:
# 2019-06-06 13:36:59,451 : INFO : loading projection weights from ../resources/embeddings_size100_win6_neg5_lr0.09_epo10.vec
# 2019-06-06 13:36:59,463 : WARNING : this function is deprecated, use smart_open.open instead
# 2019-06-06 13:37:05,958 : INFO : loaded (37875, 100) matrix from ../resources/embeddings_size100_win6_neg5_lr0.09_epo10.vec

# %%
model.most_similar("implement_bn:00082712v", topn=10)
# Out:
# 2019-06-06 13:37:09,640 : INFO : precomputing L2-norms of word weight vectors
# [('enforce_bn:00082712v', 0.7438431978225708),
#  ('apply_bn:00082712v', 0.7320846319198608),
#  ('enact_bn:00087588v', 0.7089376449584961),
#  ('comply_bn:00082139v', 0.7011393308639526),
#  ('implement_bn:00084595v', 0.6828522682189941),
#  ('incorporate_bn:00089664v', 0.6734563112258911),
#  ('implement_bn:00089621v', 0.6428806781768799),
#  ('adopt_bn:00082381v', 0.632200300693512),
#  ('transpose_bn:00095123v', 0.6135905385017395),
#  ('devise_bn:00086753v', 0.6077699661254883)]

# %%
from sklearn.manifold import TSNE
import numpy as np

keys = ['believe_bn:00083369v', 'agree_bn:00082476v', 'field_bn:00007985n', 'power_bn:00063940n', 'implement_bn:00082712v']

embedding_clusters = []
word_clusters = []
for word in keys:
    embeddings = []
    words = []
    for similar_word, _ in model.most_similar(word, topn=20):
        words.append(similar_word)
        embeddings.append(model[similar_word])
    embedding_clusters.append(embeddings)
    word_clusters.append(words)
    
embedding_clusters = np.array(embedding_clusters)
n, m, k = embedding_clusters.shape
tsne_model_en_2d = TSNE(perplexity=15, n_components=2, init='pca', n_iter=3500, random_state=32)
embeddings_en_2d = np.array(tsne_model_en_2d.fit_transform(embedding_clusters.reshape(n * m, k))).reshape(n, m, 2)

# %%
tsne_similar_words_plot('Similar words to some randomly selected sense embeddings', keys, embeddings_en_2d, word_clusters, 0.7, 'similar_words.png')
# Out:
# 2019-06-06 13:37:32,815 : WARNING : 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 2019-06-06 13:37:32,825 : WARNING : 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 2019-06-06 13:37:32,833 : WARNING : 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 2019-06-06 13:37:32,842 : WARNING : 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 2019-06-06 13:37:32,851 : WARNING : 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
from sklearn.manifold import TSNE
import numpy as np

keys = ["love", "sex", "smart", "student", "plane", "car"]


embedding_clusters = []
word_clusters = []
for word in keys:
    senses, embeddings = get_first_similar_words(word, model)
    embedding_clusters.append(embeddings)
    word_clusters.append(senses)
    
embedding_clusters = np.array(embedding_clusters)
n, m, k = embedding_clusters.shape
tsne_model_en_2d = TSNE(perplexity=15, n_components=2, init='pca', n_iter=3500, random_state=32)
embeddings_en_2d = np.array(tsne_model_en_2d.fit_transform(embedding_clusters.reshape(n * m, k))).reshape(n, m, 2)

# %%
tsne_similar_words_plot('Senses of some word taken from the combined.tab file', keys, embeddings_en_2d, word_clusters, 0.7, 'similar_words2.png')
# Out:
# 2019-06-06 13:38:05,659 : WARNING : 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 2019-06-06 13:38:05,664 : WARNING : 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 2019-06-06 13:38:05,670 : WARNING : 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 2019-06-06 13:38:05,677 : WARNING : 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 2019-06-06 13:38:05,683 : WARNING : 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 2019-06-06 13:38:05,689 : WARNING : 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
